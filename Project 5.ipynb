# %% [markdown]
# # Project 2
# Mitchell Morrison and Christian Gould

# %% [markdown]
# We have decided to use the COVID 19 dataset in pair with a dataset of holidays and their dates around the world. We plan on enriching the COVID dataset by showing the relationship between the period following a holiday and the level of covid in the country celebrating. The COVID dataset was gathered for the purpose of testing it in conjunction with holiday data.
#
# Dataset links:
# 1. https://www.kaggle.com/sandhyakrishnan02/latest-covid-19-dataset-worldwide
# 2. https://www.kaggle.com/vbmokin/covid19-holidays-of-countries?select=holidays_df_of_70_countries_for_covid_19.csv

# %% [markdown]
# # Part 1 - Getting Started
# Import libraries
# Load original Data (which ever one you chose from the provided list) into a data frame.
# Load your additional data set(s) into a data frame.
# In a markdown cell, provide a brief description of your the data sets you've chosen to work with.
# Develop a list of 3 - 4 questions that you hope to be able to answer after the exploration of the data and write them in this section.
#
# # Part 2 - Data Inspection
# Write some code to summarize the datasets. Think about the following questions:
#
# What type of data is each variable? (think like a data scientist here, not a computer scientist)<br>
# What is the total size of the data sets?<br>
# What time boundaries are there in the dataset? IOW, what time frame do they span?<br>
# Are there any missing values in any of the variables?<br>
# Do this with Intentionality. Don't skimp.<br>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Understanding our datasets

# %% [markdown]
# ### Holidays dataset

# %%
holidays = pd.read_csv('datasets/holidays_df_of_70_countries_for_covid_19.csv')
holidays.head()
# Out:
#   ds_holidays                                            holiday          ds  \
# 0  2020-02-24                   Día de Carnaval [Carnival's Day]  2020-03-02
# 1  2020-02-25                   Día de Carnaval [Carnival's Day]  2020-03-03
# 2  2020-03-24  Día Nacional de la Memoria por la Verdad y la ...  2020-03-31
# 3  2020-04-09  Semana Santa (Jueves Santo)  [Holy day (Holy T...  2020-04-16
# 4  2020-04-10  Semana Santa (Viernes Santo)  [Holy day (Holy ...  2020-04-17
#
#      country code country_official_name  lower_window  upper_window  \
# 0  Argentina   AR    Argentine Republic            -3             3
# 1  Argentina   AR    Argentine Republic            -3             3
# 2  Argentina   AR    Argentine Republic            -3             3
# 3  Argentina   AR    Argentine Republic            -3             3
# 4  Argentina   AR    Argentine Republic            -3             3
#
#    prior_scale                                         source
# 0           10  https://github.com/dr-prodigy/python-holidays
# 1           10  https://github.com/dr-prodigy/python-holidays
# 2           10  https://github.com/dr-prodigy/python-holidays
# 3           10  https://github.com/dr-prodigy/python-holidays
# 4           10  https://github.com/dr-prodigy/python-holidays

# %%
holidays.columns
# Out:
# Index(['ds_holidays', 'holiday', 'ds', 'country', 'code',
#        'country_official_name', 'lower_window', 'upper_window', 'prior_scale',
#        'source'],
#       dtype='object')

# %%
holidays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 806 entries, 0 to 805
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ds_holidays            806 non-null    object
#  1   holiday                806 non-null    object
#  2   ds                     806 non-null    object
#  3   country                806 non-null    object
#  4   code                   806 non-null    object
#  5   country_official_name  806 non-null    object
#  6   lower_window           806 non-null    int64
#  7   upper_window           806 non-null    int64
#  8   prior_scale            806 non-null    int64
#  9   source                 806 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 63.1+ KB

# %% [markdown]
# All holidays are in a Date string format and the countries and country codes are all strings. The lower and upper window variables are ints.

# %%
holidays.describe()
# Out:
#        lower_window  upper_window  prior_scale
# count         806.0         806.0        806.0
# mean           -3.0           3.0         10.0
# std             0.0           0.0          0.0
# min            -3.0           3.0         10.0
# 25%            -3.0           3.0         10.0
# 50%            -3.0           3.0         10.0
# 75%            -3.0           3.0         10.0
# max            -3.0           3.0         10.0

# %% [markdown]
# This .describe means nothing to us because all the columns of interest are categorical. We are really only using this table to gather the holidays dates and the corresponding country where the holiday is celebrated.

# %%
min(holidays.ds), max(holidays.ds)
# Out:
# ('2020-01-28', '2021-01-07')

# %% [markdown]
# The holidays dataset ranges in dates from Jan 28th 2020 to Jan 7th 2021.

# %% [markdown]
# ### COVID 19 dataset

# %%
covid = pd.read_csv('datasets/owid-covid-data.csv')
covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
columnsOfInterest = ['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
        'new_cases_smoothed', 'total_deaths', 'new_deaths', 'total_cases_per_million',
        'new_cases_per_million', 'new_cases_smoothed_per_million']
covid[columnsOfInterest]
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 153167      ZWE    Africa     Zimbabwe  2022-01-04     217678.0     1591.0
# 153168      ZWE    Africa     Zimbabwe  2022-01-05     219057.0     1379.0
# 153169      ZWE    Africa     Zimbabwe  2022-01-06     220178.0     1121.0
# 153170      ZWE    Africa     Zimbabwe  2022-01-07     221282.0     1104.0
# 153171      ZWE    Africa     Zimbabwe  2022-01-08     221918.0      636.0
#
#         new_cases_smoothed  total_deaths  new_deaths  total_cases_per_million  \
# 0                      NaN           NaN         NaN                    0.126
# 1                      NaN           NaN         NaN                    0.126
# 2                      NaN           NaN         NaN                    0.126
# 3                      NaN           NaN         NaN                    0.126
# 4                      NaN           NaN         NaN                    0.126
# ...                    ...           ...         ...                      ...
# 153167            1447.143        5078.0        31.0                14423.240
# 153168            1644.143        5092.0        14.0                14514.612
# 153169            1207.143        5108.0        16.0                14588.889
# 153170            1146.286        5136.0        28.0                14662.039
# 153171            1100.571        5148.0        12.0                14704.180
#
#         new_cases_per_million  new_cases_smoothed_per_million
# 0                       0.126                             NaN
# 1                       0.000                             NaN
# 2                       0.000                             NaN
# 3                       0.000                             NaN
# 4                       0.000                             NaN
# ...                       ...                             ...
# 153167                105.419                          95.887
# 153168                 91.372                         108.940
# 153169                 74.277                          79.985
# 153170                 73.151                          75.952
# 153171                 42.141                          72.923
#
# [153172 rows x 12 columns]

# %%
covid = covid[columnsOfInterest]

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153172 entries, 0 to 153171
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   iso_code                        153172 non-null  object
#  1   continent                       143944 non-null  object
#  2   location                        153172 non-null  object
#  3   date                            153172 non-null  object
#  4   total_cases                     150522 non-null  float64
#  5   new_cases                       150431 non-null  float64
#  6   new_cases_smoothed              149280 non-null  float64
#  7   total_deaths                    133279 non-null  float64
#  8   new_deaths                      133441 non-null  float64
#  9   total_cases_per_million         149820 non-null  float64
#  10  new_cases_per_million           149729 non-null  float64
#  11  new_cases_smoothed_per_million  148583 non-null  float64
# dtypes: float64(8), object(4)
# memory usage: 14.0+ MB

# %%
covid.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.505220e+05  1.504310e+05        1.492800e+05  1.332790e+05
# mean   2.140423e+06  8.514960e+03        8.362923e+03  5.286023e+04
# std    1.268426e+07  5.147776e+04        4.782771e+04  2.779311e+05
# min    1.000000e+00 -7.434700e+04       -6.223000e+03  1.000000e+00
# 25%    1.581250e+03  1.000000e+00        5.857000e+00  6.800000e+01
# 50%    2.077650e+04  7.000000e+01        9.200000e+01  6.770000e+02
# 75%    2.566742e+05  9.250000e+02        9.758927e+02  6.467500e+03
# max    3.051916e+08  2.879121e+06        2.265658e+06  5.484782e+06
#
#           new_deaths  total_cases_per_million  new_cases_per_million  \
# count  133441.000000            149820.000000          149729.000000
# mean      170.514032             23484.220297             107.848851
# std       831.031112             38303.228732             376.402439
# min     -1918.000000                 0.001000           -3125.829000
# 25%         0.000000               514.036750               0.023000
# 50%         2.000000              4015.258000              10.076000
# 75%        19.000000             30741.449500              86.812000
# max     18062.000000            341391.525000           51427.491000
#
#        new_cases_smoothed_per_million
# count                   148583.000000
# mean                       104.305831
# std                        253.818949
# min                       -272.971000
# 25%                          1.444000
# 50%                         15.922000
# 75%                         99.436000
# max                       7842.850000

# %% [markdown]
# This .describe function explains to us many variables related to the cases counts in many locations. However, this data does not give light to many of the different countries and the scale of the differences in their values.

# %%
min(covid.date), max(covid.date)
# Out:
# ('2020-01-01', '2022-01-08')

# %%
covid.isna().sum()
# Out:
# iso_code                              0
# continent                          9228
# location                              0
# date                                  0
# total_cases                        2650
# new_cases                          2741
# new_cases_smoothed                 3892
# total_deaths                      19893
# new_deaths                        19731
# total_cases_per_million            3352
# new_cases_per_million              3443
# new_cases_smoothed_per_million     4589
# dtype: int64

# %%
covid[covid["location"] == "Albania"].head()
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1381      ALB    Europe  Albania  2020-02-25          NaN        NaN
# 1382      ALB    Europe  Albania  2020-02-26          NaN        NaN
# 1383      ALB    Europe  Albania  2020-02-27          NaN        NaN
# 1384      ALB    Europe  Albania  2020-02-28          NaN        NaN
# 1385      ALB    Europe  Albania  2020-02-29          NaN        NaN
#
#       new_cases_smoothed  total_deaths  new_deaths  total_cases_per_million  \
# 1381                 NaN           NaN         NaN                      NaN
# 1382                 NaN           NaN         NaN                      NaN
# 1383                 NaN           NaN         NaN                      NaN
# 1384                 NaN           NaN         NaN                      NaN
# 1385                 NaN           NaN         NaN                      NaN
#
#       new_cases_per_million  new_cases_smoothed_per_million
# 1381                    NaN                             NaN
# 1382                    NaN                             NaN
# 1383                    NaN                             NaN
# 1384                    NaN                             NaN
# 1385                    NaN                             NaN

# %% [markdown]
# TODO: Make comments about empty nesss

# %% [markdown]
# ## Questions to answer
# 1. Is there a relationship between a country's holidays and COVID cases the week following?
# 2. Based on the previous question, which countries are best at mitigating new cases following holidays?
# 3. How long after holidays until cases return to normal?
# 4. Which holidays have the worst effect of COVID cases?

# %% [markdown]
# ## Merging our datasets
# ### We will merge these two dataframes using a left join on the COVID table with the country and date attributes
# It may also work to use an inner join to only keep days that are holidays and the window of transmission that we are interested in

# %% [markdown]
# # Part 3
#
# * Create a data description (data dictionary) for your data sets.
# * Describe each variable
# * If categorical, what levels are present? If the levels are encoded, what do the codes mean?
# * If numeric, provide min, max, median and any other univariate stats you'd like to add in.
# * Where appropriate, provide histograms or other visualizations to characterize each variable.
#
# ### What are our variables from the holiday dataset?
#
# * ds_holidays - date of the holiday
# * date format - YYYY-MM-DD
# * holiday - name of the holiday
#     ex. Christmas
# * ds - ds_holidays plus time delta of 7 days
# * country - country of holiday
# * code - conutry abbreviation
# * country_official_name - formal country name
# * lower_window - ds minus time delta of 3 days (early COVID onset boundary)
# * upper_window - ds plus time delta of 3 days (late COVID onset boundary)
# * prior_scale -
# * source - where holiday data is retrieved from
#
# Of these, we are only interested in: country, ds, ds_holidays
#
# This is because we are only interested in the dates of the holidays and the country that the holiday is in. ds is not necessary, but is helpful in order for us to check dates that are a week away from the holiday.
# Here is the range of the dates in the holiday set:

# %% [markdown]
# ### Variables from COVID dataset
#
# Wow, our COVID dataset has a ton of columns!! Lets narrow it down to only columns that are related to transmission and testing results. <br>
# These columns are:
# <list>
#     <li> iso_code - country code
#     <li> continent - exactly what you think
#     <li> location - country name
#     <li> date - date of record for instance
#     <li> total_cases - total covid cases for the country
#     <li> new_cases - new cases this day
#     <li> new_cases_smoothed - new cases smoothed over 7 day period
#     <li> total_deaths - total deaths for the country
#     <li> new_deaths - new deaths this day
#     <li> total_cases_per_million - ratio of total cases to million of population
#     <li> new_cases_per_million - ratio of new cases today to million of population
#     <li> new_cases_smoothed_per_million - ratio of new cases smoothed over 7 day period to million of population
#     <li> reproduction_rate - real time estimate of transmission factor of covid

# %% [markdown]
# # Part 4 - Merging
#
# To merge our COVID 19 and Holiday datasets, we need to know what columns will be used to join upon and what type of join we should use depending on the Key columns. In our case the COVID 19 dataset uses attributes location and date as the unique identifiers for each instance of data. Similarly, the Holidays dataset uses the country and ds_holidays to indicate unique holidays for each country and the date(s) it falls on.
#
# Since we will be using the COVID dataset in conjunction with holidays and more specifically, the covid data following holidays, we want to keep all instances of COVID data even if a holiday does not fall on that day of the row exactly. And since every holiday must fall on a day of the year, all of the rows in holidays will be joined on their respective row in the COVID dataset. Given that we want to keep all the COVID data, we are using a left join on the COVID table. This will however mean that there will be lots of NaN values in the holiday related columns of the new merged dataset because there is far more days in a year than holidays in a year. After all, holidays wouldn't be special if they were every day.

# %%
merged_df = pd.merge(covid, holidays,  how='left', left_on=['location','date'], right_on = ['country','ds_holidays'])

# %%
merged_df.head(10)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          5.0        0.0
# 8      AFG      Asia  Afghanistan  2020-03-03          5.0        0.0
# 9      AFG      Asia  Afghanistan  2020-03-04          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  total_cases_per_million  ...  \
# 0                 NaN           NaN         NaN                    0.126  ...
# 1                 NaN           NaN         NaN                    0.126  ...
# 2                 NaN           NaN         NaN                    0.126  ...
# 3                 NaN           NaN         NaN                    0.126  ...
# 4                 NaN           NaN         NaN                    0.126  ...
# 5               0.714           NaN         NaN                    0.126  ...
# 6               0.714           NaN         NaN                    0.126  ...
# 7               0.000           NaN         NaN                    0.126  ...
# 8               0.000           NaN         NaN                    0.126  ...
# 9               0.000           NaN         NaN                    0.126  ...
#
#    ds_holidays  holiday   ds country code country_official_name lower_window  \
# 0          NaN      NaN  NaN     NaN  NaN                   NaN          NaN
# 1          NaN      NaN  NaN     NaN  NaN                   NaN          NaN
# 2          NaN      NaN  NaN     NaN  NaN                   NaN          NaN
# 3          NaN      NaN  NaN     NaN  NaN                   NaN          NaN
# 4          NaN      NaN  NaN     NaN  NaN                   NaN          NaN
# 5          NaN      NaN  NaN     NaN  NaN                   NaN          NaN
# 6          NaN      NaN  NaN     NaN  NaN                   NaN          NaN
# 7          NaN      NaN  NaN     NaN  NaN                   NaN          NaN
# 8          NaN      NaN  NaN     NaN  NaN                   NaN          NaN
# 9          NaN      NaN  NaN     NaN  NaN                   NaN          NaN
#
#   upper_window  prior_scale  source
# 0          NaN          NaN     NaN
# 1          NaN          NaN     NaN
# 2          NaN          NaN     NaN
# 3          NaN          NaN     NaN
# 4          NaN          NaN     NaN
# 5          NaN          NaN     NaN
# 6          NaN          NaN     NaN
# 7          NaN          NaN     NaN
# 8          NaN          NaN     NaN
# 9          NaN          NaN     NaN
#
# [10 rows x 22 columns]

# %%
merged_df[merged_df["location"] == "Albania"].head()
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1381      ALB    Europe  Albania  2020-02-25          NaN        NaN
# 1382      ALB    Europe  Albania  2020-02-26          NaN        NaN
# 1383      ALB    Europe  Albania  2020-02-27          NaN        NaN
# 1384      ALB    Europe  Albania  2020-02-28          NaN        NaN
# 1385      ALB    Europe  Albania  2020-02-29          NaN        NaN
#
#       new_cases_smoothed  total_deaths  new_deaths  total_cases_per_million  \
# 1381                 NaN           NaN         NaN                      NaN
# 1382                 NaN           NaN         NaN                      NaN
# 1383                 NaN           NaN         NaN                      NaN
# 1384                 NaN           NaN         NaN                      NaN
# 1385                 NaN           NaN         NaN                      NaN
#
#       ...  ds_holidays  holiday   ds country code country_official_name  \
# 1381  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 1382  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 1383  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 1384  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 1385  ...          NaN      NaN  NaN     NaN  NaN                   NaN
#
#      lower_window upper_window  prior_scale  source
# 1381          NaN          NaN          NaN     NaN
# 1382          NaN          NaN          NaN     NaN
# 1383          NaN          NaN          NaN     NaN
# 1384          NaN          NaN          NaN     NaN
# 1385          NaN          NaN          NaN     NaN
#
# [5 rows x 22 columns]

# %%
negative_cases = merged_df[merged_df["new_cases"] < 0]
negative_cases[negative_cases["iso_code"] == "GBR"]
# Out:
#        iso_code continent        location        date  total_cases  new_cases  \
# 144530      GBR    Europe  United Kingdom  2021-04-09    4369512.0    -4860.0
# 144569      GBR    Europe  United Kingdom  2021-05-18    4454451.0    -2364.0
#
#         new_cases_smoothed  total_deaths  new_deaths  total_cases_per_million  \
# 144530            1684.857      127126.0        60.0                64062.409
# 144569            1529.000      127777.0         7.0                65307.718
#
#         ...  ds_holidays  holiday   ds country code country_official_name  \
# 144530  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 144569  ...          NaN      NaN  NaN     NaN  NaN                   NaN
#
#        lower_window upper_window  prior_scale  source
# 144530          NaN          NaN          NaN     NaN
# 144569          NaN          NaN          NaN     NaN
#
# [2 rows x 22 columns]

# %%
GBR_data = merged_df[merged_df["iso_code"] == "GBR"] 
GBR_data[GBR_data["date"].between("2021-04-01", "2021-04-11")]
# Out:
#        iso_code continent        location        date  total_cases  new_cases  \
# 144522      GBR    Europe  United Kingdom  2021-04-01    4354316.0     4479.0
# 144523      GBR    Europe  United Kingdom  2021-04-02    4357718.0     3402.0
# 144524      GBR    Europe  United Kingdom  2021-04-03    4361141.0     3423.0
# 144525      GBR    Europe  United Kingdom  2021-04-04    4363438.0     2297.0
# 144526      GBR    Europe  United Kingdom  2021-04-05    4366200.0     2762.0
# 144527      GBR    Europe  United Kingdom  2021-04-06    4368580.0     2380.0
# 144528      GBR    Europe  United Kingdom  2021-04-07    4371342.0     2762.0
# 144529      GBR    Europe  United Kingdom  2021-04-08    4374372.0     3030.0
# 144530      GBR    Europe  United Kingdom  2021-04-09    4369512.0    -4860.0
# 144531      GBR    Europe  United Kingdom  2021-04-10    4372096.0     2584.0
# 144532      GBR    Europe  United Kingdom  2021-04-11    4373826.0     1730.0
#
#         new_cases_smoothed  total_deaths  new_deaths  total_cases_per_million  \
# 144522            4448.857      126850.0        51.0                63839.616
# 144523            4051.000      126902.0        52.0                63889.494
# 144524            3987.857      126912.0        10.0                63939.679
# 144525            3764.286      126922.0        10.0                63973.356
# 144526            3494.000      126948.0        26.0                64013.851
# 144527            3256.429      126968.0        20.0                64048.744
# 144528            3072.143      127013.0        45.0                64089.239
# 144529            2865.143      127066.0        53.0                64133.662
# 144530            1684.857      127126.0        60.0                64062.409
# 144531            1565.000      127166.0        40.0                64100.293
# 144532            1484.000      127173.0         7.0                64125.657
#
#         ...  ds_holidays  holiday   ds country code country_official_name  \
# 144522  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 144523  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 144524  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 144525  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 144526  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 144527  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 144528  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 144529  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 144530  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 144531  ...          NaN      NaN  NaN     NaN  NaN                   NaN
# 144532  ...          NaN      NaN  NaN     NaN  NaN                   NaN
#
#        lower_window upper_window  prior_scale  source
# 144522          NaN          NaN          NaN     NaN
# 144523          NaN          NaN          NaN     NaN
# 144524          NaN          NaN          NaN     NaN
# 144525          NaN          NaN          NaN     NaN
# 144526          NaN          NaN          NaN     NaN
# 144527          NaN          NaN          NaN     NaN
# 144528          NaN          NaN          NaN     NaN
# 144529          NaN          NaN          NaN     NaN
# 144530          NaN          NaN          NaN     NaN
# 144531          NaN          NaN          NaN     NaN
# 144532          NaN          NaN          NaN     NaN
#
# [11 rows x 22 columns]

# %% [markdown]
# # Part 5 - Explore Bivariate relationships
#
# * Choose a reasoned set of variables to explore further. You don't have to explore all possible pairs of variables, nor do we want to grade that much. Choose 7 - 9 variables. One should be a variable that you'd like to predict (target variable) using the others (predictor variables).
# * List your predictor variables
# * List your target variable
# * Briefly describe why you have chosen these.
# * Use any of the available visualizations from Seaborn to explore the relationships between the variables. Explore the relationships among the predictor variables as well as the relationship between each predictor variable and the target variable. Which of the predictor variables are most strongly related? Are there any interesting relationships between categorical predictors and numeric predictors? If there are any dichotomous variables, does that influence any of the relationships? Are the relationships positive or negative?
#
# Below each plot, you should provide a description and interpretation of the plot. Make sure to include why the variables in that plot were chosen and what you hope the reader would gain from it as well.

# %% [markdown]
# To explore the relationships between our variables and to answer the questions we have defined in part 1, we need to define what our prdictor and target variables are.
#
# Out target variables are the columns new_cases and new_cases_per_million. This is because we are trying to uncover relationships between our other variables and the COVID cases the following week. Using new_cases_per_million as a target variable will let us more accurately compare results across different countries since their sizes/populations are different. We will also just use new_cases because this will also give us meaningful information (with respect to the country that the data belongs).
#
# We will use the holiday dates from the holiday dataset as our main relationship variable. This is because we are trying to explore the relationship between holidays and COVID spikes following that day. Other predictor variables include the country and previous new_cases. Our variables are not predictors, we are trying to explore the relationship between these target and "predictors".
#
# We have chosen the date of the holiday and the country as the predictors because these variables are specific to the COVID data we have been given and thus can only explore the relationship we see between dates, country, and cases. From the last few years, it has become clear that we cannot predict COVID just using the previous new_cases data, similar to how stocks cannot be predicted using historical prices.

# %% [markdown]
# ### We need to reduce our tables to usable data
#
# We need to get rid of all instances of country COVID data that do not exist in the holiday table.

# %%
countryGroups = merged_df.groupby('location')
for k, v in countryGroups:
    if all(v["holiday"].isnull()):
        merged_df.drop(merged_df[merged_df['location'] == k].index, inplace = True)
merged_df["location"].unique()
# Out:
# array(['Albania', 'Argentina', 'Australia', 'Austria', 'Bangladesh',
#        'Belarus', 'Belgium', 'Brazil', 'Bulgaria', 'Burundi', 'Canada',
#        'Chile', 'China', 'Colombia', 'Croatia', 'Czechia', 'Denmark',
#        'Dominican Republic', 'Egypt', 'Estonia', 'Finland', 'France',
#        'Georgia', 'Germany', 'Greece', 'Honduras', 'Hungary', 'Iceland',
#        'India', 'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan',
#        'Kenya', 'Latvia', 'Lithuania', 'Luxembourg', 'Malaysia', 'Mexico',
#        'Moldova', 'Morocco', 'Netherlands', 'New Zealand', 'Nicaragua',
#        'Nigeria', 'Norway', 'Pakistan', 'Paraguay', 'Peru', 'Philippines',
#        'Poland', 'Portugal', 'Romania', 'Serbia', 'Singapore', 'Slovakia',
#        'Slovenia', 'South Africa', 'Spain', 'Sweden', 'Switzerland',
#        'Thailand', 'Turkey', 'Ukraine', 'United Kingdom', 'United States'],
#       dtype=object)

# %% [markdown]
# We also need to drop rows that do not have COVID case data

# %%
merged_df.dropna(subset=["new_cases"], inplace=True)

# %%
merged_df[merged_df["location"] == "Albania"].head(10)
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1394      ALB    Europe  Albania  2020-03-09          2.0        2.0
# 1395      ALB    Europe  Albania  2020-03-10         10.0        8.0
# 1396      ALB    Europe  Albania  2020-03-11         12.0        2.0
# 1397      ALB    Europe  Albania  2020-03-12         23.0       11.0
# 1398      ALB    Europe  Albania  2020-03-13         33.0       10.0
# 1399      ALB    Europe  Albania  2020-03-14         38.0        5.0
# 1400      ALB    Europe  Albania  2020-03-15         42.0        4.0
# 1401      ALB    Europe  Albania  2020-03-16         51.0        9.0
# 1402      ALB    Europe  Albania  2020-03-17         55.0        4.0
# 1403      ALB    Europe  Albania  2020-03-18         59.0        4.0
#
#       new_cases_smoothed  total_deaths  new_deaths  total_cases_per_million  \
# 1394                 NaN           NaN         NaN                    0.696
# 1395                 NaN           NaN         NaN                    3.481
# 1396                 NaN           1.0         1.0                    4.177
# 1397                 NaN           1.0         0.0                    8.006
# 1398                 NaN           1.0         0.0                   11.487
# 1399               5.429           1.0         0.0                   13.227
# 1400               6.000           1.0         0.0                   14.619
# 1401               7.000           1.0         0.0                   17.752
# 1402               6.429           1.0         0.0                   19.144
# 1403               6.714           2.0         1.0                   20.536
#
#       ...  ds_holidays     holiday          ds  country code  \
# 1394  ...          NaN         NaN         NaN      NaN  NaN
# 1395  ...          NaN         NaN         NaN      NaN  NaN
# 1396  ...          NaN         NaN         NaN      NaN  NaN
# 1397  ...          NaN         NaN         NaN      NaN  NaN
# 1398  ...          NaN         NaN         NaN      NaN  NaN
# 1399  ...   2020-03-14  Summer Day  2020-03-21  Albania   AL
# 1400  ...          NaN         NaN         NaN      NaN  NaN
# 1401  ...          NaN         NaN         NaN      NaN  NaN
# 1402  ...          NaN         NaN         NaN      NaN  NaN
# 1403  ...          NaN         NaN         NaN      NaN  NaN
#
#      country_official_name lower_window upper_window  prior_scale  \
# 1394                   NaN          NaN          NaN          NaN
# 1395                   NaN          NaN          NaN          NaN
# 1396                   NaN          NaN          NaN          NaN
# 1397                   NaN          NaN          NaN          NaN
# 1398                   NaN          NaN          NaN          NaN
# 1399   Republic of Albania         -3.0          3.0         10.0
# 1400                   NaN          NaN          NaN          NaN
# 1401                   NaN          NaN          NaN          NaN
# 1402                   NaN          NaN          NaN          NaN
# 1403                   NaN          NaN          NaN          NaN
#
#                                                  source
# 1394                                                NaN
# 1395                                                NaN
# 1396                                                NaN
# 1397                                                NaN
# 1398                                                NaN
# 1399  https://en.wikipedia.org/wiki/Public_holidays_...
# 1400                                                NaN
# 1401                                                NaN
# 1402                                                NaN
# 1403                                                NaN
#
# [10 rows x 22 columns]

# %% [markdown]
# ### First relationship exploration - Holidays and COVID cases 7 days later
#
# First we will explore how holidays and COVID cases are related 7 days later for each country.

# %%
from datetime import timedelta

merged_df["7_days_later"] = merged_df["date"].shift(-7)
merged_df["7_days_later_cases"] = np.nan

merged_df.head()
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1394      ALB    Europe  Albania  2020-03-09          2.0        2.0
# 1395      ALB    Europe  Albania  2020-03-10         10.0        8.0
# 1396      ALB    Europe  Albania  2020-03-11         12.0        2.0
# 1397      ALB    Europe  Albania  2020-03-12         23.0       11.0
# 1398      ALB    Europe  Albania  2020-03-13         33.0       10.0
#
#       new_cases_smoothed  total_deaths  new_deaths  total_cases_per_million  \
# 1394                 NaN           NaN         NaN                    0.696
# 1395                 NaN           NaN         NaN                    3.481
# 1396                 NaN           1.0         1.0                    4.177
# 1397                 NaN           1.0         0.0                    8.006
# 1398                 NaN           1.0         0.0                   11.487
#
#       ...   ds  country code country_official_name lower_window upper_window  \
# 1394  ...  NaN      NaN  NaN                   NaN          NaN          NaN
# 1395  ...  NaN      NaN  NaN                   NaN          NaN          NaN
# 1396  ...  NaN      NaN  NaN                   NaN          NaN          NaN
# 1397  ...  NaN      NaN  NaN                   NaN          NaN          NaN
# 1398  ...  NaN      NaN  NaN                   NaN          NaN          NaN
#
#      prior_scale source  7_days_later  7_days_later_cases
# 1394         NaN    NaN    2020-03-16                 NaN
# 1395         NaN    NaN    2020-03-17                 NaN
# 1396         NaN    NaN    2020-03-18                 NaN
# 1397         NaN    NaN    2020-03-19                 NaN
# 1398         NaN    NaN    2020-03-20                 NaN
#
# [5 rows x 24 columns]

# %%
# %time
for row in merged_df.iterrows():
#     print(row)
    new_cases = merged_df.loc[merged_df["date"] == row[1]["7_days_later"]]
    new_cases = new_cases.loc[merged_df["location"] == row[1]["location"]]
#     print(row[0], new_cases["new_cases"])
    if (new_cases["new_cases"].dtype is float):
        merged_df.at[row[0], "7_days_later_cases"] = new_cases["new_cases"] 
merged_df.new_cases.fillna(0, inplace=True)

merged_df.head(15)
# Out:
# 1394 1401    9.0
# Name: new_cases, dtype: float64
# 1395 1402    4.0
# Name: new_cases, dtype: float64
# 1396 1403    4.0
# Name: new_cases, dtype: float64
# 1397 1404    5.0
# Name: new_cases, dtype: float64
# 1398 1405    6.0
# Name: new_cases, dtype: float64
# 1399 1406    6.0
# Name: new_cases, dtype: float64
# 1400 1407    13.0
# Name: new_cases, dtype: float64
# 1401 1408    15.0
# Name: new_cases, dtype: float64
# 1402 1409    19.0
# Name: new_cases, dtype: float64
# 1403 1410    23.0
# Name: new_cases, dtype: float64
# 1404 1411    28.0
# Name: new_cases, dtype: float64
# 1405 1412    12.0
# Name: new_cases, dtype: float64
# 1406 1413    11.0
# Name: new_cases, dtype: float64
# 1407 1414    15.0
# Name: new_cases, dtype: float64
# 1408 1415    11.0
# Name: new_cases, dtype: float64
# 1409 1416    20.0
# Name: new_cases, dtype: float64
# 1410 1417    16.0
# Name: new_cases, dtype: float64
# 1411 1418    18.0
# Name: new_cases, dtype: float64
# 1412 1419    27.0
# Name: new_cases, dtype: float64
# 1413 1420    29.0
# Name: new_cases, dtype: float64
# 1414 1421    28.0
# Name: new_cases, dtype: float64
# 1415 1422    16.0
# Name: new_cases, dtype: float64
# 1416 1423    6.0
# Name: new_cases, dtype: float64
# 1417 1424    17.0
# Name: new_cases, dtype: float64
# 1418 1425    9.0
# Name: new_cases, dtype: float64
# 1419 1426    7.0
# Name: new_cases, dtype: float64
# 1420 1427    17.0
# Name: new_cases, dtype: float64
# 1421 1428    13.0
# Name: new_cases, dtype: float64
# 1422 1429    21.0
# Name: new_cases, dtype: float64
# 1423 1430    8.0
# Name: new_cases, dtype: float64
# 1424 1431    19.0
# Name: new_cases, dtype: float64
# 1425 1432    24.0
# Name: new_cases, dtype: float64
# 1426 1433    21.0
# Name: new_cases, dtype: float64
# 1427 1434    9.0
# Name: new_cases, dtype: float64
# 1428 1435    14.0
# Name: new_cases, dtype: float64
# 1429 1436    22.0
# Name: new_cases, dtype: float64
# 1430 1437    25.0
# Name: new_cases, dtype: float64
# 1431 1438    25.0
# Name: new_cases, dtype: float64
# 1432 1439    29.0
# Name: new_cases, dtype: float64
# 1433 1440    15.0
# Name: new_cases, dtype: float64
# 1434 1441    34.0
# Name: new_cases, dtype: float64
# 1435 1442    14.0
# Name: new_cases, dtype: float64
# 1436 1443    10.0
# Name: new_cases, dtype: float64
# 1437 1444    14.0
# Name: new_cases, dtype: float64
# 1438 1445    16.0
# Name: new_cases, dtype: float64
# 1439 1446    7.0
# Name: new_cases, dtype: float64
# 1440 1447    9.0
# Name: new_cases, dtype: float64
# 1441 1448    7.0
# Name: new_cases, dtype: float64
# 1442 1449    6.0
# Name: new_cases, dtype: float64
# 1443 1450    8.0
# Name: new_cases, dtype: float64
# 1444 1451    17.0
# Name: new_cases, dtype: float64
# 1445 1452    12.0
# Name: new_cases, dtype: float64
# 1446 1453    10.0
# Name: new_cases, dtype: float64
# 1447 1454    8.0
# Name: new_cases, dtype: float64
# 1448 1455    6.0
# Name: new_cases, dtype: float64
# 1449 1456    12.0
# Name: new_cases, dtype: float64
# 1450 1457    4.0
# Name: new_cases, dtype: float64
# 1451 1458    4.0
# Name: new_cases, dtype: float64
# 1452 1459    4.0
# Name: new_cases, dtype: float64
# 1453 1460    18.0
# Name: new_cases, dtype: float64
# 1454 1461    18.0
# Name: new_cases, dtype: float64
# 1455 1462    17.0
# Name: new_cases, dtype: float64
# 1456 1463    13.0
# Name: new_cases, dtype: float64
# 1457 1464    2.0
# Name: new_cases, dtype: float64
# 1458 1465    1.0
# Name: new_cases, dtype: float64
# 1459 1466    15.0
# Name: new_cases, dtype: float64
# 1460 1467    5.0
# Name: new_cases, dtype: float64
# 1461 1468    12.0
# Name: new_cases, dtype: float64
# 1462 1469    8.0
# Name: new_cases, dtype: float64
# 1463 1470    9.0
# Name: new_cases, dtype: float64
# 1464 1471    6.0
# Name: new_cases, dtype: float64
# 1465 1472    25.0
# Name: new_cases, dtype: float64
# 1466 1473    21.0
# Name: new_cases, dtype: float64
# 1467 1474    26.0
# Name: new_cases, dtype: float64
# 1468 1475    23.0
# Name: new_cases, dtype: float64
# 1469 1476    23.0
# Name: new_cases, dtype: float64
# 1470 1477    15.0
# Name: new_cases, dtype: float64
# 1471 1478    6.0
# Name: new_cases, dtype: float64
# 1472 1479    21.0
# Name: new_cases, dtype: float64
# 1473 1480    20.0
# Name: new_cases, dtype: float64
# 1474 1481    13.0
# Name: new_cases, dtype: float64
# 1475 1482    15.0
# Name: new_cases, dtype: float64
# 1476 1483    20.0
# Name: new_cases, dtype: float64
# 1477 1484    14.0
# Name: new_cases, dtype: float64
# 1478 1485    17.0
# Name: new_cases, dtype: float64
# 1479 1486    36.0
# Name: new_cases, dtype: float64
# 1480 1487    42.0
# Name: new_cases, dtype: float64
# 1481 1488    44.0
# Name: new_cases, dtype: float64
# 1482 1489    31.0
# Name: new_cases, dtype: float64
# 1483 1490    48.0
# Name: new_cases, dtype: float64
# 1484 1491    57.0
# Name: new_cases, dtype: float64
# 1485 1492    69.0
# Name: new_cases, dtype: float64
# 1486 1493    82.0
# Name: new_cases, dtype: float64
# 1487 1494    50.0
# Name: new_cases, dtype: float64
# 1488 1495    66.0
# Name: new_cases, dtype: float64
# 1489 1496    50.0
# Name: new_cases, dtype: float64
# 1490 1497    53.0
# Name: new_cases, dtype: float64
# 1491 1498    71.0
# Name: new_cases, dtype: float64
# 1492 1499    33.0
# Name: new_cases, dtype: float64
# 1493 1500    52.0
# Name: new_cases, dtype: float64
# 1494 1501    67.0
# Name: new_cases, dtype: float64
# 1495 1502    78.0
# Name: new_cases, dtype: float64
# 1496 1503    77.0
# Name: new_cases, dtype: float64
# 1497 1504    61.0
# Name: new_cases, dtype: float64
# 1498 1505    72.0
# Name: new_cases, dtype: float64
# 1499 1506    64.0
# Name: new_cases, dtype: float64
# 1500 1507    69.0
# Name: new_cases, dtype: float64
# 1501 1508    45.0
# Name: new_cases, dtype: float64
# 1502 1509    82.0
# Name: new_cases, dtype: float64
# 1503 1510    90.0
# Name: new_cases, dtype: float64
# 1504 1511    67.0
# Name: new_cases, dtype: float64
# 1505 1512    74.0
# Name: new_cases, dtype: float64
# 1506 1513    71.0
# Name: new_cases, dtype: float64
# 1507 1514    74.0
# Name: new_cases, dtype: float64
# 1508 1515    68.0
# Name: new_cases, dtype: float64
# 1509 1516    82.0
# Name: new_cases, dtype: float64
# 1510 1517    90.0
# Name: new_cases, dtype: float64
# 1511 1518    93.0
# Name: new_cases, dtype: float64
# 1512 1519    83.0
# Name: new_cases, dtype: float64
# 1513 1520    117.0
# Name: new_cases, dtype: float64
# 1514 1521    96.0
# Name: new_cases, dtype: float64
# 1515 1522    85.0
# Name: new_cases, dtype: float64
# 1516 1523    99.0
# Name: new_cases, dtype: float64
# 1517 1524    55.0
# Name: new_cases, dtype: float64
# 1518 1525    102.0
# Name: new_cases, dtype: float64
# 1519 1526    82.0
# Name: new_cases, dtype: float64
# 1520 1527    81.0
# Name: new_cases, dtype: float64
# 1521 1528    119.0
# Name: new_cases, dtype: float64
# 1522 1529    68.0
# Name: new_cases, dtype: float64
# 1523 1530    108.0
# Name: new_cases, dtype: float64
# 1524 1531    104.0
# Name: new_cases, dtype: float64
# 1525 1532    67.0
# Name: new_cases, dtype: float64
# 1526 1533    126.0
# Name: new_cases, dtype: float64
# 1527 1534    117.0
# Name: new_cases, dtype: float64
# 1528 1535    117.0
# Name: new_cases, dtype: float64
# 1529 1536    108.0
# Name: new_cases, dtype: float64
# 1530 1537    92.0
# Name: new_cases, dtype: float64
# 1531 1538    79.0
# Name: new_cases, dtype: float64
# 1532 1539    120.0
# Name: new_cases, dtype: float64
# 1533 1540    123.0
# Name: new_cases, dtype: float64
# 1534 1541    101.0
# Name: new_cases, dtype: float64
# 1535 1542    130.0
# Name: new_cases, dtype: float64
# 1536 1543    139.0
# Name: new_cases, dtype: float64
# 1537 1544    127.0
# Name: new_cases, dtype: float64
# 1538 1545    135.0
# Name: new_cases, dtype: float64
# 1539 1546    124.0
# Name: new_cases, dtype: float64
# 1540 1547    136.0
# Name: new_cases, dtype: float64
# 1541 1548    125.0
# Name: new_cases, dtype: float64
# 1542 1549    140.0
# Name: new_cases, dtype: float64
# 1543 1550    141.0
# Name: new_cases, dtype: float64
# 1544 1551    154.0
# Name: new_cases, dtype: float64
# 1545 1552    146.0
# Name: new_cases, dtype: float64
# 1546 1553    143.0
# Name: new_cases, dtype: float64
# 1547 1554    120.0
# Name: new_cases, dtype: float64
# 1548 1555    119.0
# Name: new_cases, dtype: float64
# 1549 1556    155.0
# Name: new_cases, dtype: float64
# 1550 1557    158.0
# Name: new_cases, dtype: float64
# 1551 1558    155.0
# Name: new_cases, dtype: float64
# 1552 1559    152.0
# Name: new_cases, dtype: float64
# 1553 1560    156.0
# Name: new_cases, dtype: float64
# 1554 1561    152.0
# Name: new_cases, dtype: float64
# 1555 1562    178.0
# Name: new_cases, dtype: float64
# 1556 1563    154.0
# Name: new_cases, dtype: float64
# 1557 1564    168.0
# Name: new_cases, dtype: float64
# 1558 1565    156.0
# Name: new_cases, dtype: float64
# 1559 1566    112.0
# Name: new_cases, dtype: float64
# 1560 1567    84.0
# Name: new_cases, dtype: float64
# 1561 1568    101.0
# Name: new_cases, dtype: float64
# 1562 1569    133.0
# Name: new_cases, dtype: float64
# 1563 1570    93.0
# Name: new_cases, dtype: float64
# 1564 1571    122.0
# Name: new_cases, dtype: float64
# 1565 1572    116.0
# Name: new_cases, dtype: float64
# 1566 1573    123.0
# Name: new_cases, dtype: float64
# 1567 1574    135.0
# Name: new_cases, dtype: float64
# 1568 1575    153.0
# Name: new_cases, dtype: float64
# 1569 1576    151.0
# Name: new_cases, dtype: float64
# 1570 1577    147.0
# Name: new_cases, dtype: float64
# 1571 1578    151.0
# Name: new_cases, dtype: float64
# 1572 1579    156.0
# Name: new_cases, dtype: float64
# 1573 1580    161.0
# Name: new_cases, dtype: float64
# 1574 1581    164.0
# Name: new_cases, dtype: float64
# 1575 1582    168.0
# Name: new_cases, dtype: float64
# 1576 1583    167.0
# Name: new_cases, dtype: float64
# 1577 1584    152.0
# Name: new_cases, dtype: float64
# 1578 1585    144.0
# Name: new_cases, dtype: float64
# 1579 1586    132.0
# Name: new_cases, dtype: float64
# 1580 1587    125.0
# Name: new_cases, dtype: float64
# 1581 1588    153.0
# Name: new_cases, dtype: float64
# 1582 1589    159.0
# Name: new_cases, dtype: float64
# 1583 1590    150.0
# Name: new_cases, dtype: float64
# 1584 1591    131.0
# Name: new_cases, dtype: float64
# 1585 1592    121.0
# Name: new_cases, dtype: float64
# 1586 1593    134.0
# Name: new_cases, dtype: float64
# 1587 1594    124.0
# Name: new_cases, dtype: float64
# 1588 1595    108.0
# Name: new_cases, dtype: float64
# 1589 1596    106.0
# Name: new_cases, dtype: float64
# 1590 1597    132.0
# Name: new_cases, dtype: float64
# 1591 1598    127.0
# Name: new_cases, dtype: float64
# 1592 1599    131.0
# Name: new_cases, dtype: float64
# 1593 1600    157.0
# Name: new_cases, dtype: float64
# 1594 1601    159.0
# Name: new_cases, dtype: float64
# 1595 1602    152.0
# Name: new_cases, dtype: float64
# 1596 1603    149.0
# Name: new_cases, dtype: float64
# 1597 1604    144.0
# Name: new_cases, dtype: float64
# 1598 1605    158.0
# Name: new_cases, dtype: float64
# 1599 1606    162.0
# Name: new_cases, dtype: float64
# 1600 1607    169.0
# Name: new_cases, dtype: float64
# 1601 1608    167.0
# Name: new_cases, dtype: float64
# 1602 1609    165.0
# Name: new_cases, dtype: float64
# 1603 1610    168.0
# Name: new_cases, dtype: float64
# 1604 1611    171.0
# Name: new_cases, dtype: float64
# 1605 1612    182.0
# Name: new_cases, dtype: float64
# 1606 1613    203.0
# Name: new_cases, dtype: float64
# 1607 1614    257.0
# Name: new_cases, dtype: float64
# 1608 1615    289.0
# Name: new_cases, dtype: float64
# 1609 1616    273.0
# Name: new_cases, dtype: float64
# 1610 1617    281.0
# Name: new_cases, dtype: float64
# 1611 1618    295.0
# Name: new_cases, dtype: float64
# 1612 1619    301.0
# Name: new_cases, dtype: float64
# 1613 1620    297.0
# Name: new_cases, dtype: float64
# 1614 1621    302.0
# Name: new_cases, dtype: float64
# 1615 1622    306.0
# Name: new_cases, dtype: float64
# 1616 1623    302.0
# Name: new_cases, dtype: float64
# 1617 1624    299.0
# Name: new_cases, dtype: float64
# 1618 1625    288.0
# Name: new_cases, dtype: float64
# 1619 1626    284.0
# Name: new_cases, dtype: float64
# 1620 1627    311.0
# Name: new_cases, dtype: float64
# 1621 1628    275.0
# Name: new_cases, dtype: float64
# 1622 1629    319.0
# Name: new_cases, dtype: float64
# 1623 1630    241.0
# Name: new_cases, dtype: float64
# 1624 1631    327.0
# Name: new_cases, dtype: float64
# 1625 1632    321.0
# Name: new_cases, dtype: float64
# 1626 1633    381.0
# Name: new_cases, dtype: float64
# 1627 1634    396.0
# Name: new_cases, dtype: float64
# 1628 1635    421.0
# Name: new_cases, dtype: float64
# 1629 1636    489.0
# Name: new_cases, dtype: float64
# 1630 1637    495.0
# Name: new_cases, dtype: float64
# 1631 1638    501.0
# Name: new_cases, dtype: float64
# 1632 1639    525.0
# Name: new_cases, dtype: float64
# 1633 1640    563.0
# Name: new_cases, dtype: float64
# 1634 1641    507.0
# Name: new_cases, dtype: float64
# 1635 1642    410.0
# Name: new_cases, dtype: float64
# 1636 1643    490.0
# Name: new_cases, dtype: float64
# 1637 1644    532.0
# Name: new_cases, dtype: float64
# 1638 1645    597.0
# Name: new_cases, dtype: float64
# 1639 1646    602.0
# Name: new_cases, dtype: float64
# 1640 1647    694.0
# Name: new_cases, dtype: float64
# 1641 1648    711.0
# Name: new_cases, dtype: float64
# 1642 1649    786.0
# Name: new_cases, dtype: float64
# 1643 1650    836.0
# Name: new_cases, dtype: float64
# 1644 1651    737.0
# Name: new_cases, dtype: float64
# 1645 1652    565.0
# Name: new_cases, dtype: float64
# 1646 1653    795.0
# Name: new_cases, dtype: float64
# 1647 1654    744.0
# Name: new_cases, dtype: float64
# 1648 1655    644.0
# Name: new_cases, dtype: float64
# 1649 1656    656.0
# Name: new_cases, dtype: float64
# 1650 1657    645.0
# Name: new_cases, dtype: float64
# 1651 1658    545.0
# Name: new_cases, dtype: float64
# 1652 1659    835.0
# Name: new_cases, dtype: float64
# 1653 1660    557.0
# Name: new_cases, dtype: float64
# 1654 1661    832.0
# Name: new_cases, dtype: float64
# 1655 1662    705.0
# Name: new_cases, dtype: float64
# 1656 1663    782.0
# Name: new_cases, dtype: float64
# 1657 1664    801.0
# Name: new_cases, dtype: float64
# 1658 1665    846.0
# Name: new_cases, dtype: float64
# 1659 1666    840.0
# Name: new_cases, dtype: float64
# 1660 1667    695.0
# Name: new_cases, dtype: float64
# 1661 1668    753.0
# Name: new_cases, dtype: float64
# 1662 1669    752.0
# Name: new_cases, dtype: float64
# 1663 1670    873.0
# Name: new_cases, dtype: float64
# 1664 1671    802.0
# Name: new_cases, dtype: float64
# 1665 1672    879.0
# Name: new_cases, dtype: float64
# 1666 1673    788.0
# Name: new_cases, dtype: float64
# 1667 1674    661.0
# Name: new_cases, dtype: float64
# 1668 1675    809.0
# Name: new_cases, dtype: float64
# 1669 1676    637.0
# Name: new_cases, dtype: float64
# 1670 1677    787.0
# Name: new_cases, dtype: float64
# 1671 1678    580.0
# Name: new_cases, dtype: float64
# 1672 1679    538.0
# Name: new_cases, dtype: float64
# 1673 1680    461.0
# Name: new_cases, dtype: float64
# 1674 1681    422.0
# Name: new_cases, dtype: float64
# 1675 1682    389.0
# Name: new_cases, dtype: float64
# 1676 1683    503.0
# Name: new_cases, dtype: float64
# 1677 1684    510.0
# Name: new_cases, dtype: float64
# 1678 1685    553.0
# Name: new_cases, dtype: float64
# 1679 1686    375.0
# Name: new_cases, dtype: float64
# 1680 1687    499.0
# Name: new_cases, dtype: float64
# 1681 1688    318.0
# Name: new_cases, dtype: float64
# 1682 1689    574.0
# Name: new_cases, dtype: float64
# 1683 1690    581.0
# Name: new_cases, dtype: float64
# 1684 1691    589.0
# Name: new_cases, dtype: float64
# 1685 1692    0.0
# Name: new_cases, dtype: float64
# 1686 1693    675.0
# Name: new_cases, dtype: float64
# 1687 1694    447.0
# Name: new_cases, dtype: float64
# 1688 1695    185.0
# Name: new_cases, dtype: float64
# 1689 1696    660.0
# Name: new_cases, dtype: float64
# 1690 1697    725.0
# Name: new_cases, dtype: float64
# 1691 1698    697.0
# Name: new_cases, dtype: float64
# 1692 1699    673.0
# Name: new_cases, dtype: float64
# 1693 1700    655.0
# Name: new_cases, dtype: float64
# 1694 1701    562.0
# Name: new_cases, dtype: float64
# 1695 1702    376.0
# Name: new_cases, dtype: float64
# 1696 1703    656.0
# Name: new_cases, dtype: float64
# 1697 1704    707.0
# Name: new_cases, dtype: float64
# 1698 1705    660.0
# Name: new_cases, dtype: float64
# 1699 1706    641.0
# Name: new_cases, dtype: float64
# 1700 1707    581.0
# Name: new_cases, dtype: float64
# 1701 1708    474.0
# Name: new_cases, dtype: float64
# 1702 1709    292.0
# Name: new_cases, dtype: float64
# 1703 1710    586.0
# Name: new_cases, dtype: float64
# 1704 1711    670.0
# Name: new_cases, dtype: float64
# 1705 1712    678.0
# Name: new_cases, dtype: float64
# 1706 1713    739.0
# Name: new_cases, dtype: float64
# 1707 1714    786.0
# Name: new_cases, dtype: float64
# 1708 1715    833.0
# Name: new_cases, dtype: float64
# 1709 1716    538.0
# Name: new_cases, dtype: float64
# 1710 1717    879.0
# Name: new_cases, dtype: float64
# 1711 1718    876.0
# Name: new_cases, dtype: float64
# 1712 1719    887.0
# Name: new_cases, dtype: float64
# 1713 1720    896.0
# Name: new_cases, dtype: float64
# 1714 1721    901.0
# Name: new_cases, dtype: float64
# 1715 1722    876.0
# Name: new_cases, dtype: float64
# 1716 1723    865.0
# Name: new_cases, dtype: float64
# 1717 1724    942.0
# Name: new_cases, dtype: float64
# 1718 1725    1007.0
# Name: new_cases, dtype: float64
# 1719 1726    1052.0
# Name: new_cases, dtype: float64
# 1720 1727    1089.0
# Name: new_cases, dtype: float64
# 1721 1728    1130.0
# Name: new_cases, dtype: float64
# 1722 1729    1124.0
# Name: new_cases, dtype: float64
# 1723 1730    953.0
# Name: new_cases, dtype: float64
# 1724 1731    1239.0
# Name: new_cases, dtype: float64
# 1725 1732    1143.0
# Name: new_cases, dtype: float64
# 1726 1733    1105.0
# Name: new_cases, dtype: float64
# 1727 1734    1059.0
# Name: new_cases, dtype: float64
# 1728 1735    1152.0
# Name: new_cases, dtype: float64
# 1729 1736    1088.0
# Name: new_cases, dtype: float64
# 1730 1737    775.0
# Name: new_cases, dtype: float64
# 1731 1738    801.0
# Name: new_cases, dtype: float64
# 1732 1739    1075.0
# Name: new_cases, dtype: float64
# 1733 1740    1112.0
# Name: new_cases, dtype: float64
# 1734 1741    1071.0
# Name: new_cases, dtype: float64
# 1735 1742    1153.0
# Name: new_cases, dtype: float64
# 1736 1743    1184.0
# Name: new_cases, dtype: float64
# 1737 1744    1039.0
# Name: new_cases, dtype: float64
# 1738 1745    1021.0
# Name: new_cases, dtype: float64
# 1739 1746    1021.0
# Name: new_cases, dtype: float64
# 1740 1747    986.0
# Name: new_cases, dtype: float64
# 1741 1748    916.0
# Name: new_cases, dtype: float64
# 1742 1749    986.0
# Name: new_cases, dtype: float64
# 1743 1750    952.0
# Name: new_cases, dtype: float64
# 1744 1751    764.0
# Name: new_cases, dtype: float64
# 1745 1752    892.0
# Name: new_cases, dtype: float64
# 1746 1753    851.0
# Name: new_cases, dtype: float64
# 1747 1754    847.0
# Name: new_cases, dtype: float64
# 1748 1755    780.0
# Name: new_cases, dtype: float64
# 1749 1756    777.0
# Name: new_cases, dtype: float64
# 1750 1757    819.0
# Name: new_cases, dtype: float64
# 1751 1758    683.0
# Name: new_cases, dtype: float64
# 1752 1759    629.0
# Name: new_cases, dtype: float64
# 1753 1760    631.0
# Name: new_cases, dtype: float64
# 1754 1761    602.0
# Name: new_cases, dtype: float64
# 1755 1762    681.0
# Name: new_cases, dtype: float64
# 1756 1763    698.0
# Name: new_cases, dtype: float64
# 1757 1764    653.0
# Name: new_cases, dtype: float64
# 1758 1765    543.0
# Name: new_cases, dtype: float64
# 1759 1766    475.0
# Name: new_cases, dtype: float64
# 1760 1767    446.0
# Name: new_cases, dtype: float64
# 1761 1768    590.0
# Name: new_cases, dtype: float64
# 1762 1769    494.0
# Name: new_cases, dtype: float64
# 1763 1770    519.0
# Name: new_cases, dtype: float64
# 1764 1771    659.0
# Name: new_cases, dtype: float64
# 1765 1772    344.0
# Name: new_cases, dtype: float64
# 1766 1773    303.0
# Name: new_cases, dtype: float64
# 1767 1774    448.0
# Name: new_cases, dtype: float64
# 1768 1775    472.0
# Name: new_cases, dtype: float64
# 1769 1776    449.0
# Name: new_cases, dtype: float64
# 1770 1777    425.0
# Name: new_cases, dtype: float64
# 1771 1778    493.0
# Name: new_cases, dtype: float64
# 1772 1779    285.0
# Name: new_cases, dtype: float64
# 1773 1780    304.0
# Name: new_cases, dtype: float64
# 1774 1781    434.0
# Name: new_cases, dtype: float64
# 1775 1782    349.0
# Name: new_cases, dtype: float64
# 1776 1783    336.0
# Name: new_cases, dtype: float64
# 1777 1784    341.0
# Name: new_cases, dtype: float64
# 1778 1785    348.0
# Name: new_cases, dtype: float64
# 1779 1786    264.0
# Name: new_cases, dtype: float64
# 1780 1787    141.0
# Name: new_cases, dtype: float64
# 1781 1788    256.0
# Name: new_cases, dtype: float64
# 1782 1789    317.0
# Name: new_cases, dtype: float64
# 1783 1790    286.0
# Name: new_cases, dtype: float64
# 1784 1791    360.0
# Name: new_cases, dtype: float64
# 1785 1792    238.0
# Name: new_cases, dtype: float64
# 1786 1793    125.0
# Name: new_cases, dtype: float64
# 1787 1794    234.0
# Name: new_cases, dtype: float64
# 1788 1795    207.0
# Name: new_cases, dtype: float64
# 1789 1796    169.0
# Name: new_cases, dtype: float64
# 1790 1797    179.0
# Name: new_cases, dtype: float64
# 1791 1798    149.0
# Name: new_cases, dtype: float64
# 1792 1799    138.0
# Name: new_cases, dtype: float64
# 1793 1800    100.0
# Name: new_cases, dtype: float64
# 1794 1801    148.0
# Name: new_cases, dtype: float64
# 1795 1802    138.0
# Name: new_cases, dtype: float64
# 1796 1803    134.0
# Name: new_cases, dtype: float64
# 1797 1804    156.0
# Name: new_cases, dtype: float64
# 1798 1805    139.0
# Name: new_cases, dtype: float64
# 1799 1806    128.0
# Name: new_cases, dtype: float64
# 1800 1807    69.0
# Name: new_cases, dtype: float64
# 1801 1808    130.0
# Name: new_cases, dtype: float64
# 1802 1809    123.0
# Name: new_cases, dtype: float64
# 1803 1810    118.0
# Name: new_cases, dtype: float64
# 1804 1811    108.0
# Name: new_cases, dtype: float64
# 1805 1812    100.0
# Name: new_cases, dtype: float64
# 1806 1813    53.0
# Name: new_cases, dtype: float64
# 1807 1814    38.0
# Name: new_cases, dtype: float64
# 1808 1815    51.0
# Name: new_cases, dtype: float64
# 1809 1816    92.0
# Name: new_cases, dtype: float64
# 1810 1817    91.0
# Name: new_cases, dtype: float64
# 1811 1818    67.0
# Name: new_cases, dtype: float64
# 1812 1819    89.0
# Name: new_cases, dtype: float64
# 1813 1820    57.0
# Name: new_cases, dtype: float64
# 1814 1821    30.0
# Name: new_cases, dtype: float64
# 1815 1822    50.0
# Name: new_cases, dtype: float64
# 1816 1823    42.0
# Name: new_cases, dtype: float64
# 1817 1824    45.0
# Name: new_cases, dtype: float64
# 1818 1825    49.0
# Name: new_cases, dtype: float64
# 1819 1826    39.0
# Name: new_cases, dtype: float64
# 1820 1827    37.0
# Name: new_cases, dtype: float64
# 1821 1828    17.0
# Name: new_cases, dtype: float64
# 1822 1829    39.0
# Name: new_cases, dtype: float64
# 1823 1830    24.0
# Name: new_cases, dtype: float64
# 1824 1831    23.0
# Name: new_cases, dtype: float64
# 1825 1832    35.0
# Name: new_cases, dtype: float64
# 1826 1833    23.0
# Name: new_cases, dtype: float64
# 1827 1834    33.0
# Name: new_cases, dtype: float64
# 1828 1835    6.0
# Name: new_cases, dtype: float64
# 1829 1836    14.0
# Name: new_cases, dtype: float64
# 1830 1837    15.0
# Name: new_cases, dtype: float64
# 1831 1838    20.0
# Name: new_cases, dtype: float64
# 1832 1839    21.0
# Name: new_cases, dtype: float64
# 1833 1840    12.0
# Name: new_cases, dtype: float64
# 1834 1841    12.0
# Name: new_cases, dtype: float64
# 1835 1842    6.0
# Name: new_cases, dtype: float64
# 1836 1843    22.0
# Name: new_cases, dtype: float64
# 1837 1844    14.0
# Name: new_cases, dtype: float64
# 1838 1845    9.0
# Name: new_cases, dtype: float64
# 1839 1846    12.0
# Name: new_cases, dtype: float64
# 1840 1847    2.0
# Name: new_cases, dtype: float64
# 1841 1848    5.0
# Name: new_cases, dtype: float64
# 1842 1849    5.0
# Name: new_cases, dtype: float64
# 1843 1850    13.0
# Name: new_cases, dtype: float64
# 1844 1851    18.0
# Name: new_cases, dtype: float64
# 1845 1852    11.0
# Name: new_cases, dtype: float64
# 1846 1853    11.0
# Name: new_cases, dtype: float64
# 1847 1854    12.0
# Name: new_cases, dtype: float64
# 1848 1855    10.0
# Name: new_cases, dtype: float64
# 1849 1856    2.0
# Name: new_cases, dtype: float64
# 1850 1857    8.0
# Name: new_cases, dtype: float64
# 1851 1858    7.0
# Name: new_cases, dtype: float64
# 1852 1859    5.0
# Name: new_cases, dtype: float64
# 1853 1860    3.0
# Name: new_cases, dtype: float64
# 1854 1861    4.0
# Name: new_cases, dtype: float64
# 1855 1862    2.0
# Name: new_cases, dtype: float64
# 1856 1863    0.0
# Name: new_cases, dtype: float64
# 1857 1864    6.0
# Name: new_cases, dtype: float64
# 1858 1865    1.0
# Name: new_cases, dtype: float64
# 1859 1866    2.0
# Name: new_cases, dtype: float64
# 1860 1867    7.0
# Name: new_cases, dtype: float64
# 1861 1868    3.0
# Name: new_cases, dtype: float64
# 1862 1869    3.0
# Name: new_cases, dtype: float64
# 1863 1870    1.0
# Name: new_cases, dtype: float64
# 1864 1871    1.0
# Name: new_cases, dtype: float64
# 1865 1872    7.0
# Name: new_cases, dtype: float64
# 1866 1873    2.0
# Name: new_cases, dtype: float64
# 1867 1874    3.0
# Name: new_cases, dtype: float64
# 1868 1875    8.0
# Name: new_cases, dtype: float64
# 1869 1876    1.0
# Name: new_cases, dtype: float64
# 1870 1877    2.0
# Name: new_cases, dtype: float64
# 1871 1878    7.0
# Name: new_cases, dtype: float64
# 1872 1879    13.0
# Name: new_cases, dtype: float64
# 1873 1880    8.0
# Name: new_cases, dtype: float64
# 1874 1881    15.0
# Name: new_cases, dtype: float64
# 1875 1882    7.0
# Name: new_cases, dtype: float64
# 1876 1883    5.0
# Name: new_cases, dtype: float64
# 1877 1884    5.0
# Name: new_cases, dtype: float64
# 1878 1885    11.0
# Name: new_cases, dtype: float64
# 1879 1886    8.0
# Name: new_cases, dtype: float64
# 1880 1887    13.0
# Name: new_cases, dtype: float64
# 1881 1888    18.0
# Name: new_cases, dtype: float64
# 1882 1889    18.0
# Name: new_cases, dtype: float64
# 1883 1890    21.0
# Name: new_cases, dtype: float64
# 1884 1891    11.0
# Name: new_cases, dtype: float64
# 1885 1892    43.0
# Name: new_cases, dtype: float64
# 1886 1893    23.0
# Name: new_cases, dtype: float64
# 1887 1894    34.0
# Name: new_cases, dtype: float64
# 1888 1895    31.0
# Name: new_cases, dtype: float64
# 1889 1896    25.0
# Name: new_cases, dtype: float64
# 1890 1897    22.0
# Name: new_cases, dtype: float64
# 1891 1898    16.0
# Name: new_cases, dtype: float64
# 1892 1899    31.0
# Name: new_cases, dtype: float64
# 1893 1900    30.0
# Name: new_cases, dtype: float64
# 1894 1901    47.0
# Name: new_cases, dtype: float64
# 1895 1902    37.0
# Name: new_cases, dtype: float64
# 1896 1903    45.0
# Name: new_cases, dtype: float64
# 1897 1904    40.0
# Name: new_cases, dtype: float64
# 1898 1905    25.0
# Name: new_cases, dtype: float64
# 1899 1906    65.0
# Name: new_cases, dtype: float64
# 1900 1907    99.0
# Name: new_cases, dtype: float64
# 1901 1908    132.0
# Name: new_cases, dtype: float64
# 1902 1909    149.0
# Name: new_cases, dtype: float64
# 1903 1910    139.0
# Name: new_cases, dtype: float64
# 1904 1911    182.0
# Name: new_cases, dtype: float64
# 1905 1912    69.0
# Name: new_cases, dtype: float64
# 1906 1913    220.0
# Name: new_cases, dtype: float64
# 1907 1914    286.0
# Name: new_cases, dtype: float64
# 1908 1915    274.0
# Name: new_cases, dtype: float64
# 1909 1916    379.0
# Name: new_cases, dtype: float64
# 1910 1917    410.0
# Name: new_cases, dtype: float64
# 1911 1918    397.0
# Name: new_cases, dtype: float64
# 1912 1919    200.0
# Name: new_cases, dtype: float64
# 1913 1920    451.0
# Name: new_cases, dtype: float64
# 1914 1921    477.0
# Name: new_cases, dtype: float64
# 1915 1922    522.0
# Name: new_cases, dtype: float64
# 1916 1923    535.0
# Name: new_cases, dtype: float64
# 1917 1924    658.0
# Name: new_cases, dtype: float64
# 1918 1925    534.0
# Name: new_cases, dtype: float64
# 1919 1926    397.0
# Name: new_cases, dtype: float64
# 1920 1927    800.0
# Name: new_cases, dtype: float64
# 1921 1928    844.0
# Name: new_cases, dtype: float64
# 1922 1929    888.0
# Name: new_cases, dtype: float64
# 1923 1930    921.0
# Name: new_cases, dtype: float64
# 1924 1931    905.0
# Name: new_cases, dtype: float64
# 1925 1932    768.0
# Name: new_cases, dtype: float64
# 1926 1933    486.0
# Name: new_cases, dtype: float64
# 1927 1934    1054.0
# Name: new_cases, dtype: float64
# 1928 1935    982.0
# Name: new_cases, dtype: float64
# 1929 1936    853.0
# Name: new_cases, dtype: float64
# 1930 1937    895.0
# Name: new_cases, dtype: float64
# 1931 1938    984.0
# Name: new_cases, dtype: float64
# 1932 1939    896.0
# Name: new_cases, dtype: float64
# 1933 1940    502.0
# Name: new_cases, dtype: float64
# 1934 1941    740.0
# Name: new_cases, dtype: float64
# 1935 1942    1079.0
# Name: new_cases, dtype: float64
# 1936 1943    998.0
# Name: new_cases, dtype: float64
# 1937 1944    977.0
# Name: new_cases, dtype: float64
# 1938 1945    869.0
# Name: new_cases, dtype: float64
# 1939 1946    864.0
# Name: new_cases, dtype: float64
# 1940 1947    410.0
# Name: new_cases, dtype: float64
# 1941 1948    995.0
# Name: new_cases, dtype: float64
# 1942 1949    992.0
# Name: new_cases, dtype: float64
# 1943 1950    942.0
# Name: new_cases, dtype: float64
# 1944 1951    959.0
# Name: new_cases, dtype: float64
# 1945 1952    849.0
# Name: new_cases, dtype: float64
# 1946 1953    780.0
# Name: new_cases, dtype: float64
# 1947 1954    451.0
# Name: new_cases, dtype: float64
# 1948 1955    872.0
# Name: new_cases, dtype: float64
# 1949 1956    820.0
# Name: new_cases, dtype: float64
# 1950 1957    768.0
# Name: new_cases, dtype: float64
# 1951 1958    826.0
# Name: new_cases, dtype: float64
# 1952 1959    664.0
# Name: new_cases, dtype: float64
# 1953 1960    539.0
# Name: new_cases, dtype: float64
# 1954 1961    295.0
# Name: new_cases, dtype: float64
# 1955 1962    594.0
# Name: new_cases, dtype: float64
# 1956 1963    680.0
# Name: new_cases, dtype: float64
# 1957 1964    669.0
# Name: new_cases, dtype: float64
# 1958 1965    647.0
# Name: new_cases, dtype: float64
# 1959 1966    549.0
# Name: new_cases, dtype: float64
# 1960 1967    467.0
# Name: new_cases, dtype: float64
# 1961 1968    0.0
# Name: new_cases, dtype: float64
# 1962 1969    824.0
# Name: new_cases, dtype: float64
# 1963 1970    572.0
# Name: new_cases, dtype: float64
# 1964 1971    533.0
# Name: new_cases, dtype: float64
# 1965 1972    445.0
# Name: new_cases, dtype: float64
# 1966 1973    475.0
# Name: new_cases, dtype: float64
# 1967 1974    325.0
# Name: new_cases, dtype: float64
# 1968 1975    195.0
# Name: new_cases, dtype: float64
# 1969 1976    501.0
# Name: new_cases, dtype: float64
# 1970 1977    508.0
# Name: new_cases, dtype: float64
# 1971 1978    495.0
# Name: new_cases, dtype: float64
# 1972 1979    441.0
# Name: new_cases, dtype: float64
# 1973 1980    428.0
# Name: new_cases, dtype: float64
# 1974 1981    435.0
# Name: new_cases, dtype: float64
# 1975 1982    217.0
# Name: new_cases, dtype: float64
# 1976 1983    616.0
# Name: new_cases, dtype: float64
# 1977 1984    659.0
# Name: new_cases, dtype: float64
# 1978 1985    566.0
# Name: new_cases, dtype: float64
# 1979 1986    594.0
# Name: new_cases, dtype: float64
# 1980 1987    629.0
# Name: new_cases, dtype: float64
# 1981 1988    444.0
# Name: new_cases, dtype: float64
# 1982 1989    264.0
# Name: new_cases, dtype: float64
# 1983 1990    650.0
# Name: new_cases, dtype: float64
# 1984 1991    672.0
# Name: new_cases, dtype: float64
# 1985 1992    591.0
# Name: new_cases, dtype: float64
# 1986 1993    467.0
# Name: new_cases, dtype: float64
# 1987 1994    547.0
# Name: new_cases, dtype: float64
# 1988 1995    413.0
# Name: new_cases, dtype: float64
# 1989 1996    197.0
# Name: new_cases, dtype: float64
# 1990 1997    725.0
# Name: new_cases, dtype: float64
# 1991 1998    571.0
# Name: new_cases, dtype: float64
# 1992 1999    570.0
# Name: new_cases, dtype: float64
# 1993 2000    631.0
# Name: new_cases, dtype: float64
# 1994 2001    0.0
# Name: new_cases, dtype: float64
# 1995 2002    1131.0
# Name: new_cases, dtype: float64
# 1996 2003    230.0
# Name: new_cases, dtype: float64
# 1997 2004    770.0
# Name: new_cases, dtype: float64
# 1998 2005    690.0
# Name: new_cases, dtype: float64
# 1999 2006    625.0
# Name: new_cases, dtype: float64
# 2000 2007    573.0
# Name: new_cases, dtype: float64
# 2001 2008    587.0
# Name: new_cases, dtype: float64
# 2002 2009    475.0
# Name: new_cases, dtype: float64
# 2003 2010    194.0
# Name: new_cases, dtype: float64
# 2004 2011    587.0
# Name: new_cases, dtype: float64
# 2005 2012    616.0
# Name: new_cases, dtype: float64
# 2006 2013    549.0
# Name: new_cases, dtype: float64
# 2007 2014    502.0
# Name: new_cases, dtype: float64
# 2008 2015    465.0
# Name: new_cases, dtype: float64
# 2009 2016    0.0
# Name: new_cases, dtype: float64
# 2010 2017    623.0
# Name: new_cases, dtype: float64
# 2011 2018    556.0
# Name: new_cases, dtype: float64
# 2012 2019    609.0
# Name: new_cases, dtype: float64
# 2013 2020    516.0
# Name: new_cases, dtype: float64
# 2014 2021    440.0
# Name: new_cases, dtype: float64
# 2015 2022    405.0
# Name: new_cases, dtype: float64
# 2016 2023    418.0
# Name: new_cases, dtype: float64
# 2017 2024    195.0
# Name: new_cases, dtype: float64
# 2018 2025    195.0
# Name: new_cases, dtype: float64
# 2019 2026    228.0
# Name: new_cases, dtype: float64
# 2020 2027    466.0
# Name: new_cases, dtype: float64
# 2021 2028    406.0
# Name: new_cases, dtype: float64
# 2022 2029    357.0
# Name: new_cases, dtype: float64
# 2023 2030    328.0
# Name: new_cases, dtype: float64
# 2024 2031    172.0
# Name: new_cases, dtype: float64
# 2025 2032    393.0
# Name: new_cases, dtype: float64
# 2026 2033    346.0
# Name: new_cases, dtype: float64
# 2027 2034    222.0
# Name: new_cases, dtype: float64
# 2028 2035    352.0
# Name: new_cases, dtype: float64
# 2029 2036    309.0
# Name: new_cases, dtype: float64
# 2030 2037    263.0
# Name: new_cases, dtype: float64
# 2031 2038    138.0
# Name: new_cases, dtype: float64
# 2032 2039    376.0
# Name: new_cases, dtype: float64
# 2033 2040    326.0
# Name: new_cases, dtype: float64
# 2034 2041    301.0
# Name: new_cases, dtype: float64
# 2035 2042    296.0
# Name: new_cases, dtype: float64
# 2036 2043    325.0
# Name: new_cases, dtype: float64
# 2037 2044    228.0
# Name: new_cases, dtype: float64
# 2038 2045    120.0
# Name: new_cases, dtype: float64
# 2039 2046    376.0
# Name: new_cases, dtype: float64
# 2040 2047    343.0
# Name: new_cases, dtype: float64
# 2041 2048    319.0
# Name: new_cases, dtype: float64
# 2042 2049    286.0
# Name: new_cases, dtype: float64
# 2043 2050    321.0
# Name: new_cases, dtype: float64
# 2044 2051    167.0
# Name: new_cases, dtype: float64
# 2045 2052    0.0
# Name: new_cases, dtype: float64
# 2046 2053    643.0
# Name: new_cases, dtype: float64
# 2047 2054    547.0
# Name: new_cases, dtype: float64
# 2048 2055    0.0
# Name: new_cases, dtype: float64
# 2049 2056    1325.0
# Name: new_cases, dtype: float64
# 2050 2057    0.0
# Name: new_cases, dtype: float64
# 2051 2058    661.0
# Name: new_cases, dtype: float64
# 2052 2059    0.0
# Name: new_cases, dtype: float64
# 2053 2060    1136.0
# Name: new_cases, dtype: float64
# 2054 2061    0.0
# Name: new_cases, dtype: float64
# 2055 2062    1236.0
# Name: new_cases, dtype: float64
# 2056 2063    1648.0
# Name: new_cases, dtype: float64
# 2057 Series([], Name: new_cases, dtype: float64)
# 2058 Series([], Name: new_cases, dtype: float64)
# 2059 Series([], Name: new_cases, dtype: float64)
# 2060 Series([], Name: new_cases, dtype: float64)
# 2061 Series([], Name: new_cases, dtype: float64)
# 2062 Series([], Name: new_cases, dtype: float64)
# 2063 1394    2.0
# Name: new_cases, dtype: float64
# 5468 5475    5.0
# Name: new_cases, dtype: float64
# 5469 5476    2.0
# Name: new_cases, dtype: float64
# 5470 5477    0.0
# Name: new_cases, dtype: float64
# 5471 5478    12.0
# Name: new_cases, dtype: float64
# 5472 5479    3.0
# Name: new_cases, dtype: float64
# 5473 5480    11.0
# Name: new_cases, dtype: float64
# 5474 5481    11.0
# Name: new_cases, dtype: float64
# 5475 5482    12.0
# Name: new_cases, dtype: float64
# 5476 5483    11.0
# Name: new_cases, dtype: float64
# 5477 5484    18.0
# Name: new_cases, dtype: float64
# 5478 5485    31.0
# Name: new_cases, dtype: float64
# 5479 5486    30.0
# Name: new_cases, dtype: float64
# 5480 5487    108.0
# Name: new_cases, dtype: float64
# 5481 5488    35.0
# Name: new_cases, dtype: float64
# 5482 5489    86.0
# Name: new_cases, dtype: float64
# 5483 5490    0.0
# Name: new_cases, dtype: float64
# 5484 5491    115.0
# Name: new_cases, dtype: float64
# 5485 5492    87.0
# Name: new_cases, dtype: float64
# 5486 5493    101.0
# Name: new_cases, dtype: float64
# 5487 5494    55.0
# Name: new_cases, dtype: float64
# 5488 5495    75.0
# Name: new_cases, dtype: float64
# 5489 5496    234.0
# Name: new_cases, dtype: float64
# 5490 5497    0.0
# Name: new_cases, dtype: float64
# 5491 5498    79.0
# Name: new_cases, dtype: float64
# 5492 5499    132.0
# Name: new_cases, dtype: float64
# 5493 5500    186.0
# Name: new_cases, dtype: float64
# 5494 5501    0.0
# Name: new_cases, dtype: float64
# 5495 5502    103.0
# Name: new_cases, dtype: float64
# 5496 5503    74.0
# Name: new_cases, dtype: float64
# 5497 5504    87.0
# Name: new_cases, dtype: float64
# 5498 5505    80.0
# Name: new_cases, dtype: float64
# 5499 5506    180.0
# Name: new_cases, dtype: float64
# 5500 5507    0.0
# Name: new_cases, dtype: float64
# 5501 5508    167.0
# Name: new_cases, dtype: float64
# 5502 5509    66.0
# Name: new_cases, dtype: float64
# 5503 5510    69.0
# Name: new_cases, dtype: float64
# 5504 5511    166.0
# Name: new_cases, dtype: float64
# 5505 5512    128.0
# Name: new_cases, dtype: float64
# 5506 5513    98.0
# Name: new_cases, dtype: float64
# 5507 5514    89.0
# Name: new_cases, dtype: float64
# 5508 5515    81.0
# Name: new_cases, dtype: float64
# 5509 5516    102.0
# Name: new_cases, dtype: float64
# 5510 5517    90.0
# Name: new_cases, dtype: float64
# 5511 5518    113.0
# Name: new_cases, dtype: float64
# 5512 5519    291.0
# Name: new_cases, dtype: float64
# 5513 5520    172.0
# Name: new_cases, dtype: float64
# 5514 5521    173.0
# Name: new_cases, dtype: float64
# 5515 5522    112.0
# Name: new_cases, dtype: float64
# 5516 5523    111.0
# Name: new_cases, dtype: float64
# 5517 5524    124.0
# Name: new_cases, dtype: float64
# 5518 5525    158.0
# Name: new_cases, dtype: float64
# 5519 5526    143.0
# Name: new_cases, dtype: float64
# 5520 5527    104.0
# Name: new_cases, dtype: float64
# 5521 5528    149.0
# Name: new_cases, dtype: float64
# 5522 5529    102.0
# Name: new_cases, dtype: float64
# 5523 5530    104.0
# Name: new_cases, dtype: float64
# 5524 5531    133.0
# Name: new_cases, dtype: float64
# 5525 5532    188.0
# Name: new_cases, dtype: float64
# 5526 5533    163.0
# Name: new_cases, dtype: float64
# 5527 5534    240.0
# Name: new_cases, dtype: float64
# 5528 5535    165.0
# Name: new_cases, dtype: float64
# 5529 5536    258.0
# Name: new_cases, dtype: float64
# 5530 5537    244.0
# Name: new_cases, dtype: float64
# 5531 5538    285.0
# Name: new_cases, dtype: float64
# 5532 5539    316.0
# Name: new_cases, dtype: float64
# 5533 5540    255.0
# Name: new_cases, dtype: float64
# 5534 5541    345.0
# Name: new_cases, dtype: float64
# 5535 5542    326.0
# Name: new_cases, dtype: float64
# 5536 5543    263.0
# Name: new_cases, dtype: float64
# 5537 5544    303.0
# Name: new_cases, dtype: float64
# 5538 5545    438.0
# Name: new_cases, dtype: float64
# 5539 5546    474.0
# Name: new_cases, dtype: float64
# 5540 5547    648.0
# Name: new_cases, dtype: float64
# 5541 5548    718.0
# Name: new_cases, dtype: float64
# 5542 5549    704.0
# Name: new_cases, dtype: float64
# 5543 5550    723.0
# Name: new_cases, dtype: float64
# 5544 5551    552.0
# Name: new_cases, dtype: float64
# 5545 5552    600.0
# Name: new_cases, dtype: float64
# 5546 5553    705.0
# Name: new_cases, dtype: float64
# 5547 5554    769.0
# Name: new_cases, dtype: float64
# 5548 5555    717.0
# Name: new_cases, dtype: float64
# 5549 5556    795.0
# Name: new_cases, dtype: float64
# 5550 5557    637.0
# Name: new_cases, dtype: float64
# 5551 5558    564.0
# Name: new_cases, dtype: float64
# 5552 5559    904.0
# Name: new_cases, dtype: float64
# 5553 5560    949.0
# Name: new_cases, dtype: float64
# 5554 5561    929.0
# Name: new_cases, dtype: float64
# 5555 5562    840.0
# Name: new_cases, dtype: float64
# 5556 5563    983.0
# Name: new_cases, dtype: float64
# 5557 5564    774.0
# Name: new_cases, dtype: float64
# 5558 5565    826.0
# Name: new_cases, dtype: float64
# 5559 5566    1141.0
# Name: new_cases, dtype: float64
# 5560 5567    1226.0
# Name: new_cases, dtype: float64
# 5561 5568    1386.0
# Name: new_cases, dtype: float64
# 5562 5569    1391.0
# Name: new_cases, dtype: float64
# 5563 5570    1531.0
# Name: new_cases, dtype: float64
# 5564 5571    1282.0
# Name: new_cases, dtype: float64
# 5565 5572    1208.0
# Name: new_cases, dtype: float64
# 5566 5573    1374.0
# Name: new_cases, dtype: float64
# 5567 5574    1393.0
# Name: new_cases, dtype: float64
# 5568 5575    1958.0
# Name: new_cases, dtype: float64
# 5569 5576    2060.0
# Name: new_cases, dtype: float64
# 5570 5577    1634.0
# Name: new_cases, dtype: float64
# 5571 5578    1581.0
# Name: new_cases, dtype: float64
# 5572 5579    2146.0
# Name: new_cases, dtype: float64
# 5573 5580    2272.0
# Name: new_cases, dtype: float64
# 5574 5581    2648.0
# Name: new_cases, dtype: float64
# 5575 5582    2606.0
# Name: new_cases, dtype: float64
# 5576 5583    2886.0
# Name: new_cases, dtype: float64
# 5577 5584    2401.0
# Name: new_cases, dtype: float64
# 5578 5585    2189.0
# Name: new_cases, dtype: float64
# 5579 5586    2335.0
# Name: new_cases, dtype: float64
# 5580 5587    2262.0
# Name: new_cases, dtype: float64
# 5581 5588    2667.0
# Name: new_cases, dtype: float64
# 5582 5589    2744.0
# Name: new_cases, dtype: float64
# 5583 5590    2845.0
# Name: new_cases, dtype: float64
# 5584 5591    2590.0
# Name: new_cases, dtype: float64
# 5585 5592    2439.0
# Name: new_cases, dtype: float64
# 5586 5593    2632.0
# Name: new_cases, dtype: float64
# 5587 5594    2979.0
# Name: new_cases, dtype: float64
# 5588 5595    3604.0
# Name: new_cases, dtype: float64
# 5589 5596    3663.0
# Name: new_cases, dtype: float64
# 5590 5597    3367.0
# Name: new_cases, dtype: float64
# 5591 5598    3449.0
# Name: new_cases, dtype: float64
# 5592 5599    2657.0
# Name: new_cases, dtype: float64
# 5593 5600    3099.0
# Name: new_cases, dtype: float64
# 5594 5601    3645.0
# Name: new_cases, dtype: float64
# 5595 5602    4236.0
# Name: new_cases, dtype: float64
# 5596 5603    3637.0
# Name: new_cases, dtype: float64
# 5597 5604    4518.0
# Name: new_cases, dtype: float64
# 5598 5605    3223.0
# Name: new_cases, dtype: float64
# 5599 5606    4231.0
# Name: new_cases, dtype: float64
# 5600 5607    4019.0
# Name: new_cases, dtype: float64
# 5601 5608    5344.0
# Name: new_cases, dtype: float64
# 5602 5609    5782.0
# Name: new_cases, dtype: float64
# 5603 5610    6127.0
# Name: new_cases, dtype: float64
# 5604 5611    5493.0
# Name: new_cases, dtype: float64
# 5605 5612    4814.0
# Name: new_cases, dtype: float64
# 5606 5613    4192.0
# Name: new_cases, dtype: float64
# 5607 5614    4890.0
# Name: new_cases, dtype: float64
# 5608 5615    5939.0
# Name: new_cases, dtype: float64
# 5609 5616    5641.0
# Name: new_cases, dtype: float64
# 5610 5617    6377.0
# Name: new_cases, dtype: float64
# 5611 5618    5929.0
# Name: new_cases, dtype: float64
# 5612 5619    5241.0
# Name: new_cases, dtype: float64
# 5613 5620    5376.0
# Name: new_cases, dtype: float64
# 5614 5621    4824.0
# Name: new_cases, dtype: float64
# 5615 5622    6792.0
# Name: new_cases, dtype: float64
# 5616 5623    7147.0
# Name: new_cases, dtype: float64
# 5617 5624    7513.0
# Name: new_cases, dtype: float64
# 5618 5625    7482.0
# Name: new_cases, dtype: float64
# 5619 5626    6134.0
# Name: new_cases, dtype: float64
# 5620 5627    4688.0
# Name: new_cases, dtype: float64
# 5621 5628    7369.0
# Name: new_cases, dtype: float64
# 5622 5629    7043.0
# Name: new_cases, dtype: float64
# 5623 5630    7663.0
# Name: new_cases, dtype: float64
# 5624 5631    7498.0
# Name: new_cases, dtype: float64
# 5625 5632    6365.0
# Name: new_cases, dtype: float64
# 5626 5633    6663.0
# Name: new_cases, dtype: float64
# 5627 5634    5469.0
# Name: new_cases, dtype: float64
# 5628 5635    4557.0
# Name: new_cases, dtype: float64
# 5629 5636    6840.0
# Name: new_cases, dtype: float64
# 5630 5637    6693.0
# Name: new_cases, dtype: float64
# 5631 5638    8225.0
# Name: new_cases, dtype: float64
# 5632 5639    8159.0
# Name: new_cases, dtype: float64
# 5633 5640    7759.0
# Name: new_cases, dtype: float64
# 5634 5641    5352.0
# Name: new_cases, dtype: float64
# 5635 5642    8713.0
# Name: new_cases, dtype: float64
# 5636 5643    8771.0
# Name: new_cases, dtype: float64
# 5637 5644    10550.0
# Name: new_cases, dtype: float64
# 5638 5645    10104.0
# Name: new_cases, dtype: float64
# 5639 5646    11717.0
# Name: new_cases, dtype: float64
# 5640 5647    9230.0
# Name: new_cases, dtype: float64
# 5641 5648    7187.0
# Name: new_cases, dtype: float64
# 5642 5649    9309.0
# Name: new_cases, dtype: float64
# 5643 5650    10504.0
# Name: new_cases, dtype: float64
# 5644 5651    10933.0
# Name: new_cases, dtype: float64
# 5645 5652    12026.0
# Name: new_cases, dtype: float64
# 5646 5653    10684.0
# Name: new_cases, dtype: float64
# 5647 5654    9924.0
# Name: new_cases, dtype: float64
# 5648 5655    6986.0
# Name: new_cases, dtype: float64
# 5649 5656    9215.0
# Name: new_cases, dtype: float64
# 5650 5657    12027.0
# Name: new_cases, dtype: float64
# 5651 5658    12259.0
# Name: new_cases, dtype: float64
# 5652 5659    11905.0
# Name: new_cases, dtype: float64
# 5653 5660    11507.0
# Name: new_cases, dtype: float64
# 5654 5661    10776.0
# Name: new_cases, dtype: float64
# 5655 5662    9056.0
# Name: new_cases, dtype: float64
# 5656 5663    9909.0
# Name: new_cases, dtype: float64
# 5657 5664    11892.0
# Name: new_cases, dtype: float64
# 5658 5665    11674.0
# Name: new_cases, dtype: float64
# 5659 5666    12701.0
# Name: new_cases, dtype: float64
# 5660 5667    11945.0
# Name: new_cases, dtype: float64
# 5661 5668    9276.0
# Name: new_cases, dtype: float64
# 5662 5669    8431.0
# Name: new_cases, dtype: float64
# 5663 5670    8782.0
# Name: new_cases, dtype: float64
# 5664 5671    12027.0
# Name: new_cases, dtype: float64
# 5665 5672    12625.0
# Name: new_cases, dtype: float64
# 5666 5673    13467.0
# Name: new_cases, dtype: float64
# 5667 5674    12969.0
# Name: new_cases, dtype: float64
# 5668 5675    11249.0
# Name: new_cases, dtype: float64
# 5669 5676    8841.0
# Name: new_cases, dtype: float64
# 5670 5677    11807.0
# Name: new_cases, dtype: float64
# 5671 5678    13477.0
# Name: new_cases, dtype: float64
# 5672 5679    14392.0
# Name: new_cases, dtype: float64
# 5673 5680    14001.0
# Name: new_cases, dtype: float64
# 5674 5681    14687.0
# Name: new_cases, dtype: float64
# 5675 5682    11129.0
# Name: new_cases, dtype: float64
# 5676 5683    7668.0
# Name: new_cases, dtype: float64
# 5677 5684    11242.0
# Name: new_cases, dtype: float64
# 5678 5685    14740.0
# Name: new_cases, dtype: float64
# 5679 5686    16447.0
# Name: new_cases, dtype: float64
# 5680 5687    15454.0
# Name: new_cases, dtype: float64
# 5681 5688    15099.0
# Name: new_cases, dtype: float64
# 5682 5689    12414.0
# Name: new_cases, dtype: float64
# 5683 5690    10324.0
# Name: new_cases, dtype: float64
# 5684 5691    9524.0
# Name: new_cases, dtype: float64
# 5685 5692    13305.0
# Name: new_cases, dtype: float64
# 5686 5693    14932.0
# Name: new_cases, dtype: float64
# 5687 5694    17096.0
# Name: new_cases, dtype: float64
# 5688 5695    16546.0
# Name: new_cases, dtype: float64
# 5689 5696    13510.0
# Name: new_cases, dtype: float64
# 5690 5697    10561.0
# Name: new_cases, dtype: float64
# 5691 5698    12982.0
# Name: new_cases, dtype: float64
# 5692 5699    16337.0
# Name: new_cases, dtype: float64
# 5693 5700    18326.0
# Name: new_cases, dtype: float64
# 5694 5701    16325.0
# Name: new_cases, dtype: float64
# 5695 5702    15718.0
# Name: new_cases, dtype: float64
# 5696 5703    11968.0
# Name: new_cases, dtype: float64
# 5697 5704    9253.0
# Name: new_cases, dtype: float64
# 5698 5705    11712.0
# Name: new_cases, dtype: float64
# 5699 5706    14308.0
# Name: new_cases, dtype: float64
# 5700 5707    13924.0
# Name: new_cases, dtype: float64
# 5701 5708    13267.0
# Name: new_cases, dtype: float64
# 5702 5709    13379.0
# Name: new_cases, dtype: float64
# 5703 5710    9745.0
# Name: new_cases, dtype: float64
# 5704 5711    6609.0
# Name: new_cases, dtype: float64
# 5705 5712    9598.0
# Name: new_cases, dtype: float64
# 5706 5713    12145.0
# Name: new_cases, dtype: float64
# 5707 5714    10652.0
# Name: new_cases, dtype: float64
# 5708 5715    11100.0
# Name: new_cases, dtype: float64
# 5709 5716    11786.0
# Name: new_cases, dtype: float64
# 5710 5717    8037.0
# Name: new_cases, dtype: float64
# 5711 5718    5331.0
# Name: new_cases, dtype: float64
# 5712 5719    8317.0
# Name: new_cases, dtype: float64
# 5713 5720    11977.0
# Name: new_cases, dtype: float64
# 5714 5721    10880.0
# Name: new_cases, dtype: float64
# 5715 5722    11163.0
# Name: new_cases, dtype: float64
# 5716 5723    11859.0
# Name: new_cases, dtype: float64
# 5717 5724    8468.0
# Name: new_cases, dtype: float64
# 5718 5725    5645.0
# Name: new_cases, dtype: float64
# 5719 5726    7893.0
# Name: new_cases, dtype: float64
# 5720 5727    10621.0
# Name: new_cases, dtype: float64
# 5721 5728    10332.0
# Name: new_cases, dtype: float64
# 5722 5729    10097.0
# Name: new_cases, dtype: float64
# 5723 5730    9608.0
# Name: new_cases, dtype: float64
# 5724 5731    7140.0
# Name: new_cases, dtype: float64
# 5725 5732    4184.0
# Name: new_cases, dtype: float64
# 5726 5733    4265.0
# Name: new_cases, dtype: float64
# 5727 5734    7164.0
# Name: new_cases, dtype: float64
# 5728 5735    8593.0
# Name: new_cases, dtype: float64
# 5729 5736    9043.0
# Name: new_cases, dtype: float64
# 5730 5737    7846.0
# Name: new_cases, dtype: float64
# 5731 5738    6098.0
# Name: new_cases, dtype: float64
# 5732 5739    5432.0
# Name: new_cases, dtype: float64
# 5733 5740    5726.0
# Name: new_cases, dtype: float64
# 5734 5741    8037.0
# Name: new_cases, dtype: float64
# 5735 5742    7533.0
# Name: new_cases, dtype: float64
# 5736 5743    7629.0
# Name: new_cases, dtype: float64
# 5737 5744    6899.0
# Name: new_cases, dtype: float64
# 5738 5745    5201.0
# Name: new_cases, dtype: float64
# 5739 5746    3278.0
# Name: new_cases, dtype: float64
# 5740 5747    3199.0
# ...
# Name: new_cases, dtype: float64
# 145345 145352    54665.0
# Name: new_cases, dtype: float64
# 145346 145353    119395.0
# Name: new_cases, dtype: float64
# 145347 145354    26111.0
# Name: new_cases, dtype: float64
# 145348 145355    26138.0
# Name: new_cases, dtype: float64
# 145349 145356    85089.0
# Name: new_cases, dtype: float64
# 145350 145357    68739.0
# Name: new_cases, dtype: float64
# 145351 145358    69439.0
# Name: new_cases, dtype: float64
# 145352 145359    79290.0
# Name: new_cases, dtype: float64
# 145353 145360    188071.0
# Name: new_cases, dtype: float64
# 145354 145361    34220.0
# Name: new_cases, dtype: float64
# 145355 145362    43840.0
# Name: new_cases, dtype: float64
# 145356 145363    117751.0
# Name: new_cases, dtype: float64
# 145357 145364    103201.0
# Name: new_cases, dtype: float64
# 145358 145365    96672.0
# Name: new_cases, dtype: float64
# 145359 145366    110923.0
# Name: new_cases, dtype: float64
# 145360 145367    255297.0
# Name: new_cases, dtype: float64
# 145361 145368    51473.0
# Name: new_cases, dtype: float64
# 145362 145369    29324.0
# Name: new_cases, dtype: float64
# 145363 145370    175901.0
# Name: new_cases, dtype: float64
# 145364 145371    121210.0
# Name: new_cases, dtype: float64
# 145365 145372    156258.0
# Name: new_cases, dtype: float64
# 145366 145373    142197.0
# Name: new_cases, dtype: float64
# 145367 145374    229847.0
# Name: new_cases, dtype: float64
# 145368 145375    51829.0
# Name: new_cases, dtype: float64
# 145369 145376    44355.0
# Name: new_cases, dtype: float64
# 145370 145377    214770.0
# Name: new_cases, dtype: float64
# 145371 145378    152821.0
# Name: new_cases, dtype: float64
# 145372 145379    158628.0
# Name: new_cases, dtype: float64
# 145373 145380    157239.0
# Name: new_cases, dtype: float64
# 145374 145381    245686.0
# Name: new_cases, dtype: float64
# 145375 145382    69918.0
# Name: new_cases, dtype: float64
# 145376 145383    39009.0
# Name: new_cases, dtype: float64
# 145377 145384    231409.0
# Name: new_cases, dtype: float64
# 145378 145385    157127.0
# Name: new_cases, dtype: float64
# 145379 145386    169433.0
# Name: new_cases, dtype: float64
# 145380 145387    184447.0
# Name: new_cases, dtype: float64
# 145381 145388    243579.0
# Name: new_cases, dtype: float64
# 145382 145389    65317.0
# Name: new_cases, dtype: float64
# 145383 145390    45551.0
# Name: new_cases, dtype: float64
# 145384 145391    252008.0
# Name: new_cases, dtype: float64
# 145385 145392    171278.0
# Name: new_cases, dtype: float64
# 145386 145393    202253.0
# Name: new_cases, dtype: float64
# 145387 145394    175083.0
# Name: new_cases, dtype: float64
# 145388 145395    235593.0
# Name: new_cases, dtype: float64
# 145389 145396    74105.0
# Name: new_cases, dtype: float64
# 145390 145397    47335.0
# Name: new_cases, dtype: float64
# 145391 145398    80599.0
# Name: new_cases, dtype: float64
# 145392 145399    254798.0
# Name: new_cases, dtype: float64
# 145393 145400    183031.0
# Name: new_cases, dtype: float64
# 145394 145401    160119.0
# Name: new_cases, dtype: float64
# 145395 145402    228209.0
# Name: new_cases, dtype: float64
# 145396 145403    73627.0
# Name: new_cases, dtype: float64
# 145397 145404    42905.0
# Name: new_cases, dtype: float64
# 145398 145405    244526.0
# Name: new_cases, dtype: float64
# 145399 145406    146190.0
# Name: new_cases, dtype: float64
# 145400 145407    170585.0
# Name: new_cases, dtype: float64
# 145401 145408    155514.0
# Name: new_cases, dtype: float64
# 145402 145409    208874.0
# Name: new_cases, dtype: float64
# 145403 145410    64282.0
# Name: new_cases, dtype: float64
# 145404 145411    42201.0
# Name: new_cases, dtype: float64
# 145405 145412    188409.0
# Name: new_cases, dtype: float64
# 145406 145413    121659.0
# Name: new_cases, dtype: float64
# 145407 145414    133133.0
# Name: new_cases, dtype: float64
# 145408 145415    126474.0
# Name: new_cases, dtype: float64
# 145409 145416    176908.0
# Name: new_cases, dtype: float64
# 145410 145417    54030.0
# Name: new_cases, dtype: float64
# 145411 145418    49630.0
# Name: new_cases, dtype: float64
# 145412 145419    164666.0
# Name: new_cases, dtype: float64
# 145413 145420    111379.0
# Name: new_cases, dtype: float64
# 145414 145421    123419.0
# Name: new_cases, dtype: float64
# 145415 145422    109956.0
# Name: new_cases, dtype: float64
# 145416 145423    152877.0
# Name: new_cases, dtype: float64
# 145417 145424    44987.0
# Name: new_cases, dtype: float64
# 145418 145425    41778.0
# Name: new_cases, dtype: float64
# 145419 145426    151269.0
# Name: new_cases, dtype: float64
# 145420 145427    97379.0
# Name: new_cases, dtype: float64
# 145421 145428    110591.0
# Name: new_cases, dtype: float64
# 145422 145429    100546.0
# Name: new_cases, dtype: float64
# 145423 145430    126477.0
# Name: new_cases, dtype: float64
# 145424 145431    32838.0
# Name: new_cases, dtype: float64
# 145425 145432    37627.0
# Name: new_cases, dtype: float64
# 145426 145433    100641.0
# Name: new_cases, dtype: float64
# 145427 145434    106375.0
# Name: new_cases, dtype: float64
# 145428 145435    121576.0
# Name: new_cases, dtype: float64
# 145429 145436    86378.0
# Name: new_cases, dtype: float64
# 145430 145437    109796.0
# Name: new_cases, dtype: float64
# 145431 145438    36361.0
# Name: new_cases, dtype: float64
# 145432 145439    31932.0
# Name: new_cases, dtype: float64
# 145433 145440    102200.0
# Name: new_cases, dtype: float64
# 145434 145441    80948.0
# Name: new_cases, dtype: float64
# 145435 145442    91456.0
# Name: new_cases, dtype: float64
# 145436 145443    78899.0
# Name: new_cases, dtype: float64
# 145437 145444    95152.0
# Name: new_cases, dtype: float64
# 145438 145445    30141.0
# Name: new_cases, dtype: float64
# 145439 145446    18225.0
# Name: new_cases, dtype: float64
# 145440 145447    114302.0
# Name: new_cases, dtype: float64
# 145441 145448    68711.0
# Name: new_cases, dtype: float64
# 145442 145449    100901.0
# Name: new_cases, dtype: float64
# 145443 145450    77552.0
# Name: new_cases, dtype: float64
# 145444 145451    93585.0
# Name: new_cases, dtype: float64
# 145445 145452    32572.0
# Name: new_cases, dtype: float64
# 145446 145453    31700.0
# Name: new_cases, dtype: float64
# 145447 145454    113983.0
# Name: new_cases, dtype: float64
# 145448 145455    71117.0
# Name: new_cases, dtype: float64
# 145449 145456    84577.0
# Name: new_cases, dtype: float64
# 145450 145457    81830.0
# Name: new_cases, dtype: float64
# 145451 145458    96087.0
# Name: new_cases, dtype: float64
# 145452 145459    34058.0
# Name: new_cases, dtype: float64
# 145453 145460    35896.0
# Name: new_cases, dtype: float64
# 145454 145461    110605.0
# Name: new_cases, dtype: float64
# 145455 145462    80323.0
# Name: new_cases, dtype: float64
# 145456 145463    95021.0
# Name: new_cases, dtype: float64
# 145457 145464    57164.0
# Name: new_cases, dtype: float64
# 145458 145465    144899.0
# Name: new_cases, dtype: float64
# 145459 145466    42556.0
# Name: new_cases, dtype: float64
# 145460 145467    31093.0
# Name: new_cases, dtype: float64
# 145461 145468    136847.0
# Name: new_cases, dtype: float64
# 145462 145469    87845.0
# Name: new_cases, dtype: float64
# 145463 145470    111732.0
# Name: new_cases, dtype: float64
# 145464 145471    110350.0
# Name: new_cases, dtype: float64
# 145465 145472    125867.0
# Name: new_cases, dtype: float64
# 145466 145473    43702.0
# Name: new_cases, dtype: float64
# 145467 145474    38931.0
# Name: new_cases, dtype: float64
# 145468 145475    147706.0
# Name: new_cases, dtype: float64
# 145469 145476    92722.0
# Name: new_cases, dtype: float64
# 145470 145477    111648.0
# Name: new_cases, dtype: float64
# 145471 145478    34805.0
# Name: new_cases, dtype: float64
# 145472 145479    52090.0
# Name: new_cases, dtype: float64
# 145473 145480    25493.0
# Name: new_cases, dtype: float64
# 145474 145481    42148.0
# Name: new_cases, dtype: float64
# 145475 145482    192793.0
# Name: new_cases, dtype: float64
# 145476 145483    117485.0
# Name: new_cases, dtype: float64
# 145477 145484    138611.0
# Name: new_cases, dtype: float64
# 145478 145485    138440.0
# Name: new_cases, dtype: float64
# 145479 145486    153659.0
# Name: new_cases, dtype: float64
# 145480 145487    63622.0
# Name: new_cases, dtype: float64
# 145481 145488    49801.0
# Name: new_cases, dtype: float64
# 145482 145489    179786.0
# Name: new_cases, dtype: float64
# 145483 145490    113304.0
# Name: new_cases, dtype: float64
# 145484 145491    150872.0
# Name: new_cases, dtype: float64
# 145485 145492    122214.0
# Name: new_cases, dtype: float64
# 145486 145493    170738.0
# Name: new_cases, dtype: float64
# 145487 145494    54763.0
# Name: new_cases, dtype: float64
# 145488 145495    50568.0
# Name: new_cases, dtype: float64
# 145489 145496    187285.0
# Name: new_cases, dtype: float64
# 145490 145497    116071.0
# Name: new_cases, dtype: float64
# 145491 145498    144097.0
# Name: new_cases, dtype: float64
# 145492 145499    141707.0
# Name: new_cases, dtype: float64
# 145493 145500    192903.0
# Name: new_cases, dtype: float64
# 145494 145501    76429.0
# Name: new_cases, dtype: float64
# 145495 145502    86859.0
# Name: new_cases, dtype: float64
# 145496 145503    242086.0
# Name: new_cases, dtype: float64
# 145497 145504    178982.0
# Name: new_cases, dtype: float64
# 145498 145505    241681.0
# Name: new_cases, dtype: float64
# 145499 145506    269233.0
# Name: new_cases, dtype: float64
# 145500 145507    219462.0
# Name: new_cases, dtype: float64
# 145501 145508    57054.0
# Name: new_cases, dtype: float64
# 145502 145509    182566.0
# Name: new_cases, dtype: float64
# 145503 145510    544329.0
# Name: new_cases, dtype: float64
# 145504 145511    354683.0
# Name: new_cases, dtype: float64
# 145505 145512    497002.0
# Name: new_cases, dtype: float64
# 145506 145513    590547.0
# Name: new_cases, dtype: float64
# 145507 145514    472515.0
# Name: new_cases, dtype: float64
# 145508 145515    116442.0
# Name: new_cases, dtype: float64
# 145509 145516    248174.0
# Name: new_cases, dtype: float64
# 145510 145517    1171378.0
# Name: new_cases, dtype: float64
# 145511 145518    799189.0
# Name: new_cases, dtype: float64
# 145512 145519    623308.0
# Name: new_cases, dtype: float64
# 145513 145520    786824.0
# Name: new_cases, dtype: float64
# 145514 145521    900832.0
# Name: new_cases, dtype: float64
# 145515 145522    378692.0
# Name: new_cases, dtype: float64
# 145516 Series([], Name: new_cases, dtype: float64)
# 145517 Series([], Name: new_cases, dtype: float64)
# 145518 Series([], Name: new_cases, dtype: float64)
# 145519 Series([], Name: new_cases, dtype: float64)
# 145520 Series([], Name: new_cases, dtype: float64)
# 145521 Series([], Name: new_cases, dtype: float64)
# 145522 Series([], Name: new_cases, dtype: float64)
#      iso_code continent location        date  total_cases  new_cases  \
# 1394      ALB    Europe  Albania  2020-03-09          2.0        2.0
# 1395      ALB    Europe  Albania  2020-03-10         10.0        8.0
# 1396      ALB    Europe  Albania  2020-03-11         12.0        2.0
# 1397      ALB    Europe  Albania  2020-03-12         23.0       11.0
# 1398      ALB    Europe  Albania  2020-03-13         33.0       10.0
# 1399      ALB    Europe  Albania  2020-03-14         38.0        5.0
# 1400      ALB    Europe  Albania  2020-03-15         42.0        4.0
# 1401      ALB    Europe  Albania  2020-03-16         51.0        9.0
# 1402      ALB    Europe  Albania  2020-03-17         55.0        4.0
# 1403      ALB    Europe  Albania  2020-03-18         59.0        4.0
# 1404      ALB    Europe  Albania  2020-03-19         64.0        5.0
# 1405      ALB    Europe  Albania  2020-03-20         70.0        6.0
# 1406      ALB    Europe  Albania  2020-03-21         76.0        6.0
# 1407      ALB    Europe  Albania  2020-03-22         89.0       13.0
# 1408      ALB    Europe  Albania  2020-03-23        104.0       15.0
#
#       new_cases_smoothed  total_deaths  new_deaths  total_cases_per_million  \
# 1394                 NaN           NaN         NaN                    0.696
# 1395                 NaN           NaN         NaN                    3.481
# 1396                 NaN           1.0         1.0                    4.177
# 1397                 NaN           1.0         0.0                    8.006
# 1398                 NaN           1.0         0.0                   11.487
# 1399               5.429           1.0         0.0                   13.227
# 1400               6.000           1.0         0.0                   14.619
# 1401               7.000           1.0         0.0                   17.752
# 1402               6.429           1.0         0.0                   19.144
# 1403               6.714           2.0         1.0                   20.536
# 1404               5.857           2.0         0.0                   22.277
# 1405               5.286           2.0         0.0                   24.365
# 1406               5.429           2.0         0.0                   26.454
# 1407               6.714           2.0         0.0                   30.979
# 1408               7.571           4.0         2.0                   36.200
#
#       ...          ds  country code country_official_name lower_window  \
# 1394  ...         NaN      NaN  NaN                   NaN          NaN
# 1395  ...         NaN      NaN  NaN                   NaN          NaN
# 1396  ...         NaN      NaN  NaN                   NaN          NaN
# 1397  ...         NaN      NaN  NaN                   NaN          NaN
# 1398  ...         NaN      NaN  NaN                   NaN          NaN
# 1399  ...  2020-03-21  Albania   AL   Republic of Albania         -3.0
# 1400  ...         NaN      NaN  NaN                   NaN          NaN
# 1401  ...         NaN      NaN  NaN                   NaN          NaN
# 1402  ...         NaN      NaN  NaN                   NaN          NaN
# 1403  ...         NaN      NaN  NaN                   NaN          NaN
# 1404  ...         NaN      NaN  NaN                   NaN          NaN
# 1405  ...         NaN      NaN  NaN                   NaN          NaN
# 1406  ...         NaN      NaN  NaN                   NaN          NaN
# 1407  ...  2020-03-29  Albania   AL   Republic of Albania         -3.0
# 1408  ...         NaN      NaN  NaN                   NaN          NaN
#
#      upper_window prior_scale  \
# 1394          NaN         NaN
# 1395          NaN         NaN
# 1396          NaN         NaN
# 1397          NaN         NaN
# 1398          NaN         NaN
# 1399          3.0        10.0
# 1400          NaN         NaN
# 1401          NaN         NaN
# 1402          NaN         NaN
# 1403          NaN         NaN
# 1404          NaN         NaN
# 1405          NaN         NaN
# 1406          NaN         NaN
# 1407          3.0        10.0
# 1408          NaN         NaN
#
#                                                  source  7_days_later  \
# 1394                                                NaN    2020-03-16
# 1395                                                NaN    2020-03-17
# 1396                                                NaN    2020-03-18
# 1397                                                NaN    2020-03-19
# 1398                                                NaN    2020-03-20
# 1399  https://en.wikipedia.org/wiki/Public_holidays_...    2020-03-21
# 1400                                                NaN    2020-03-22
# 1401                                                NaN    2020-03-23
# 1402                                                NaN    2020-03-24
# 1403                                                NaN    2020-03-25
# 1404                                                NaN    2020-03-26
# 1405                                                NaN    2020-03-27
# 1406                                                NaN    2020-03-28
# 1407  https://en.wikipedia.org/wiki/Public_holidays_...    2020-03-29
# 1408                                                NaN    2020-03-30
#
#       7_days_later_cases
# 1394                 9.0
# 1395                 4.0
# 1396                 4.0
# 1397                 5.0
# 1398                 6.0
# 1399                 6.0
# 1400                13.0
# 1401                15.0
# 1402                19.0
# 1403                23.0
# 1404                28.0
# 1405                12.0
# 1406                11.0
# 1407                15.0
# 1408                11.0
#
# [15 rows x 24 columns]
